# %% [markdown]
# pandalogbook 16.05.22 \
# Analysing how the probability of making a Go response was affected by the following three within-subject factors and their interactions: required action (Go, NoGo), valence (Win; Avoid), and group (sertraline, placebo)
# - at baseline, 2 and 6 weeks separately
# - over time

# %%
import scipy.io
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from plotting import Plotting
from loading_preparing_data import Panda
import statsmodels.api as sm
import statsmodels.formula.api as smf
from pymer4.models import Lmer

# %%
# load raw data
filepath = '/Users/jolandamalamud/phd/projects/gng_panda_antler/gng_panda/data/'
panda = Panda(filepath)
D = panda.load_data()
# prep action choices to plot
data = panda.extract_data(D)
# load rct data
dfRCT = panda.load_rctdata()

# %% [markdown]
# Logistic mixed-effects models to analyse how the probability of making a Go reponse was affected by within-subject factors: required action, valence and group allocation.

# %%
data_incl = panda.extract_data(D[data['sess']==1])
taskids = data_incl['subids']
rctids = dfRCT['identifier_n']
rct_variables = dfRCT[['group','_site_n','cistotal_cat','depr_dur_2years']]
rct_variables_matched = pd.DataFrame()
for c in rct_variables.columns:
    rct_variables_matched[c] = panda.match_ids(rct_variables[c], taskids, rctids)

rt = data_incl['rt'].T.flatten()
go = data_incl['a'].T.flatten()
go[go==2] = 0
go[go==3] = np.nan
required_go = np.zeros_like(go)
required_go[(data_incl['stimuli'].T.flatten() == 1)  | (data_incl['stimuli'].T.flatten() == 2)] = 1
valence = np.zeros_like(go)
valence[(data_incl['stimuli'].T.flatten() == 1)  | (data_incl['stimuli'].T.flatten() == 3)] = 1
pavlovian = np.zeros_like(go)
pavlovian[(data_incl['stimuli'].T.flatten() == 2)  | (data_incl['stimuli'].T.flatten() == 3)] = 1
subject = np.arange(0,len(data_incl['subids']))
subject = np.repeat(subject,96)
trials = np.tile(np.arange(0,96),len(data_incl['subids']))
group = (np.repeat(rct_variables_matched['group'],96) == 2).astype(int)
site = np.repeat(rct_variables_matched['_site_n'],96)
cis = np.repeat(rct_variables_matched['cistotal_cat'],96)
dep = np.repeat(rct_variables_matched['depr_dur_2years'],96)
df = pd.DataFrame({'subject': subject, 'rt': rt, 'required': required_go, 'valence': valence, \
                   'pavlovian': pavlovian, 'group': group, 'trials': trials, 'site': site, 'cis': cis, 'dep': dep})
df = df.dropna()

model = Lmer("choice  ~ valence * required + (valence * required + 1|subject)",
         data=df, family = 'binomial')

display(model.fit())
# Out:
# Formula: choice~valence*required+(valence*required+1|subject)
#
# Family: binomial	 Inference: parametric
#
# Number of observations: 53727	 Groups: {'subject': 619.0}
#
# Log-likelihood: -29221.251 	 AIC: 58470.503
#
# Random effects:
#
#                      Name    Var    Std
# subject       (Intercept)  1.390  1.179
# subject           valence  2.805  1.675
# subject          required  1.118  1.057
# subject  valence:required  3.605  1.899
#
#                  IV1               IV2   Corr
# subject  (Intercept)           valence -0.163
# subject  (Intercept)          required -0.313
# subject  (Intercept)  valence:required  0.178
# subject      valence          required  0.320
# subject      valence  valence:required -0.588
# subject     required  valence:required -0.324
#
# Fixed effects:
#                   Estimate  2.5_ci  97.5_ci     SE     OR  OR_2.5_ci  \
# (Intercept)         -1.000  -1.103   -0.897  0.053  0.368      0.332
# valence              0.837   0.690    0.985  0.075  2.310      1.993
# required             0.725   0.621    0.828  0.053  2.064      1.861
# valence:required    -0.051  -0.228    0.126  0.090  0.951      0.796
#
#                   OR_97.5_ci   Prob  Prob_2.5_ci  Prob_97.5_ci  Z-stat  P-val  \
# (Intercept)            0.408  0.269        0.249         0.290 -18.967  0.000
# valence                2.679  0.698        0.666         0.728  11.100  0.000
# required               2.289  0.674        0.651         0.696  13.740  0.000
# valence:required       1.135  0.487        0.443         0.532  -0.561  0.575
#
#                   Sig
# (Intercept)       ***
# valence           ***
# required          ***
# valence:required

# %%
for t in range(1,4):
    data_incl = panda.extract_data(D[data['sess']==t])
    taskids = data_incl['subids']
    rctids = dfRCT['identifier_n']
    rct_variables = dfRCT[['group','_site_n','cistotal_cat','depr_dur_2years']]
    rct_variables_matched = pd.DataFrame()
    for c in rct_variables.columns:
        rct_variables_matched[c] = panda.match_ids(rct_variables[c], taskids, rctids)
        
    go = data_incl['a'].T.flatten()
    go[go==2] = 0
    go[go==3] = np.nan
    required_go = np.zeros_like(go)
    required_go[(data_incl['stimuli'].T.flatten() == 1)  | (data_incl['stimuli'].T.flatten() == 2)] = 1
    valence = np.zeros_like(go)
    valence[(data_incl['stimuli'].T.flatten() == 1)  | (data_incl['stimuli'].T.flatten() == 3)] = 1
    subject = np.arange(0,len(data_incl['subids']))
    subject = np.repeat(subject,96)
    trials = np.tile(np.arange(0,96),len(data_incl['subids']))
    group = (np.repeat(rct_variables_matched['group'],96) == 2).astype(int)
    site = np.repeat(rct_variables_matched['_site_n'],96)
    cis = np.repeat(rct_variables_matched['cistotal_cat'],96)
    dep = np.repeat(rct_variables_matched['depr_dur_2years'],96)
    df = pd.DataFrame({'subject': subject, 'choice': go, 'required': required_go, 'valence': valence, \
                       'group': group, 'trials': trials, 'site': site, 'cis': cis, 'dep': dep})
    df = df.dropna()
    
    model = Lmer("choice  ~ valence * required * group + site + cis + dep + (valence * required * group + 1|subject)",
             data=df, family = 'binomial')

    display(model.fit())
# Out:
# [1] "failure to converge in 10000 evaluations"
# [2] " \n"
#
# unable to evaluate scaled gradient
#
# Model failed to converge: degenerate  Hessian with 10 negative eigenvalues
#
# Formula: choice~valence*required*group+site+cis+dep+(valence*required*group+1|subject)
#
# Family: binomial	 Inference: parametric
#
# Number of observations: 53727	 Groups: {'subject': 619.0}
#
# Log-likelihood: -29212.837 	 AIC: 58519.674
#
# Random effects:
#
#                            Name    Var    Std
# subject             (Intercept)  1.139  1.067
# subject                 valence  2.910  1.706
# subject                required  1.128  1.062
# subject                   group  0.806  0.898
# subject        valence:required  3.648  1.910
# subject           valence:group  0.750  0.866
# subject          required:group  0.807  0.898
# subject  valence:required:group  1.001  1.001
#
#                       IV1                     IV2   Corr
# subject       (Intercept)                 valence -0.179
# subject       (Intercept)                required -0.324
# subject       (Intercept)                   group -0.156
# subject       (Intercept)        valence:required  0.149
# subject       (Intercept)           valence:group  0.084
# subject       (Intercept)          required:group -0.023
# subject       (Intercept)  valence:required:group  0.020
# subject           valence                required  0.282
# subject           valence                   group -0.073
# subject           valence        valence:required -0.569
# subject           valence           valence:group -0.331
# subject           valence          required:group  0.021
# subject           valence  valence:required:group  0.010
# subject          required                   group  0.050
# subject          required        valence:required -0.341
# subject          required           valence:group  0.075
# subject          required          required:group -0.435
# subject          required  valence:required:group  0.138
# subject             group        valence:required  0.136
# subject             group           valence:group  0.004
# subject             group          required:group -0.103
# subject             group  valence:required:group -0.044
# subject  valence:required           valence:group -0.023
# subject  valence:required          required:group -0.005
# subject  valence:required  valence:required:group -0.289
# subject     valence:group          required:group  0.008
# subject     valence:group  valence:required:group  0.006
# subject    required:group  valence:required:group -0.056
#
# Fixed effects:
#                         Estimate  2.5_ci  97.5_ci     SE     OR  OR_2.5_ci  \
# (Intercept)               -0.753  -1.172   -0.334  0.214  0.471      0.310
# valence                    0.801   0.590    1.012  0.108  2.228      1.804
# required                   0.697   0.552    0.842  0.074  2.007      1.736
# group                     -0.110  -0.316    0.097  0.105  0.896      0.729
# site                      -0.080  -0.158   -0.001  0.040  0.923      0.854
# cis                       -0.055  -0.173    0.063  0.060  0.947      0.841
# dep                        0.084  -0.115    0.283  0.101  1.087      0.891
# valence:required          -0.035  -0.284    0.214  0.127  0.965      0.752
# valence:group              0.077  -0.218    0.373  0.151  1.080      0.804
# required:group             0.057  -0.150    0.263  0.105  1.058      0.861
# valence:required:group    -0.032  -0.385    0.321  0.180  0.969      0.681
#
#                         OR_97.5_ci   Prob  Prob_2.5_ci  Prob_97.5_ci  Z-stat  \
# (Intercept)                  0.716  0.320        0.237         0.417  -3.525
# valence                      2.752  0.690        0.643         0.733   7.435
# required                     2.320  0.667        0.635         0.699   9.416
# group                        1.102  0.473        0.422         0.524  -1.039
# site                         0.999  0.480        0.461         0.500  -1.995
# cis                          1.065  0.486        0.457         0.516  -0.909
# dep                          1.326  0.521        0.471         0.570   0.826
# valence:required             1.239  0.491        0.429         0.553  -0.277
# valence:group                1.451  0.519        0.446         0.592   0.512
# required:group               1.301  0.514        0.463         0.565   0.539
# valence:required:group       1.379  0.492        0.405         0.580  -0.176
#
#                         P-val  Sig
# (Intercept)             0.000  ***
# valence                 0.000  ***
# required                0.000  ***
# group                   0.299
# site                    0.046    *
# cis                     0.363
# dep                     0.409
# valence:required        0.782
# valence:group           0.609
# required:group          0.590
# valence:required:group  0.860
# [1] "failure to converge in 10000 evaluations"
# [2] " \n"
#
# unable to evaluate scaled gradient
#
# Model failed to converge: degenerate  Hessian with 11 negative eigenvalues
#
# Formula: choice~valence*required*group+site+cis+dep+(valence*required*group+1|subject)
#
# Family: binomial	 Inference: parametric
#
# Number of observations: 46484	 Groups: {'subject': 527.0}
#
# Log-likelihood: -24149.555 	 AIC: 48393.110
#
# Random effects:
#
#                            Name    Var    Std
# subject             (Intercept)  1.097  1.047
# subject                 valence  3.978  1.994
# subject                required  1.229  1.109
# subject                   group  0.789  0.888
# subject        valence:required  4.540  2.131
# subject           valence:group  0.714  0.845
# subject          required:group  0.791  0.889
# subject  valence:required:group  1.032  1.016
#
#                       IV1                     IV2   Corr
# subject       (Intercept)                 valence -0.213
# subject       (Intercept)                required -0.115
# subject       (Intercept)                   group -0.245
# subject       (Intercept)        valence:required  0.085
# subject       (Intercept)           valence:group  0.081
# subject       (Intercept)          required:group -0.147
# subject       (Intercept)  valence:required:group  0.143
# subject           valence                required  0.302
# subject           valence                   group  0.136
# subject           valence        valence:required -0.547
# subject           valence           valence:group -0.238
# subject           valence          required:group  0.096
# subject           valence  valence:required:group -0.150
# subject          required                   group -0.241
# subject          required        valence:required -0.144
# subject          required           valence:group -0.094
# subject          required          required:group -0.106
# subject          required  valence:required:group  0.071
# subject             group        valence:required  0.001
# subject             group           valence:group -0.141
# subject             group          required:group  0.039
# subject             group  valence:required:group -0.005
# subject  valence:required           valence:group -0.131
# subject  valence:required          required:group -0.195
# subject  valence:required  valence:required:group -0.080
# subject     valence:group          required:group  0.126
# subject     valence:group  valence:required:group -0.233
# subject    required:group  valence:required:group  0.054
#
# Fixed effects:
#                         Estimate  2.5_ci  97.5_ci     SE     OR  OR_2.5_ci  \
# (Intercept)               -0.700  -1.164   -0.235  0.237  0.497      0.312
# valence                    1.044   0.782    1.305  0.133  2.840      2.187
# required                   1.016   0.854    1.179  0.083  2.763      2.349
# group                      0.138  -0.076    0.353  0.110  1.148      0.927
# site                      -0.024  -0.112    0.064  0.045  0.976      0.894
# cis                       -0.102  -0.229    0.025  0.065  0.903      0.796
# dep                       -0.072  -0.288    0.143  0.110  0.930      0.750
# valence:required           0.009  -0.289    0.308  0.152  1.009      0.749
# valence:group             -0.026  -0.395    0.344  0.189  0.975      0.673
# required:group            -0.056  -0.305    0.193  0.127  0.945      0.737
# valence:required:group    -0.111  -0.547    0.324  0.222  0.895      0.579
#
#                         OR_97.5_ci   Prob  Prob_2.5_ci  Prob_97.5_ci  Z-stat  \
# (Intercept)                  0.791  0.332        0.238         0.442  -2.950
# valence                      3.688  0.740        0.686         0.787   7.827
# required                     3.250  0.734        0.701         0.765  12.261
# group                        1.423  0.535        0.481         0.587   1.264
# site                         1.066  0.494        0.472         0.516  -0.536
# cis                          1.025  0.475        0.443         0.506  -1.580
# dep                          1.154  0.482        0.429         0.536  -0.658
# valence:required             1.360  0.502        0.428         0.576   0.061
# valence:group                1.411  0.494        0.402         0.585  -0.135
# required:group               1.212  0.486        0.424         0.548  -0.443
# valence:required:group       1.382  0.472        0.367         0.580  -0.502
#
#                         P-val  Sig
# (Intercept)             0.003   **
# valence                 0.000  ***
# required                0.000  ***
# group                   0.206
# site                    0.592
# cis                     0.114
# dep                     0.510
# valence:required        0.952
# valence:group           0.892
# required:group          0.658
# valence:required:group  0.616
# [1] "failure to converge in 10000 evaluations"
# [2] " \n"
#
# unable to evaluate scaled gradient
#
# Model failed to converge: degenerate  Hessian with 7 negative eigenvalues
#
# Formula: choice~valence*required*group+site+cis+dep+(valence*required*group+1|subject)
#
# Family: binomial	 Inference: parametric
#
# Number of observations: 42745	 Groups: {'subject': 481.0}
#
# Log-likelihood: -21516.520 	 AIC: 43127.040
#
# Random effects:
#
#                            Name    Var    Std
# subject             (Intercept)  1.574  1.255
# subject                 valence  4.296  2.073
# subject                required  2.303  1.518
# subject                   group  0.706  0.840
# subject        valence:required  4.758  2.181
# subject           valence:group  1.168  1.081
# subject          required:group  1.017  1.009
# subject  valence:required:group  1.264  1.124
#
#                       IV1                     IV2   Corr
# subject       (Intercept)                 valence -0.199
# subject       (Intercept)                required -0.256
# subject       (Intercept)                   group -0.224
# subject       (Intercept)        valence:required  0.180
# subject       (Intercept)           valence:group -0.044
# subject       (Intercept)          required:group -0.039
# subject       (Intercept)  valence:required:group  0.010
# subject           valence                required  0.131
# subject           valence                   group -0.043
# subject           valence        valence:required -0.550
# subject           valence           valence:group -0.072
# subject           valence          required:group  0.089
# subject           valence  valence:required:group -0.252
# subject          required                   group -0.104
# subject          required        valence:required -0.143
# subject          required           valence:group  0.194
# subject          required          required:group -0.278
# subject          required  valence:required:group -0.018
# subject             group        valence:required  0.034
# subject             group           valence:group -0.141
# subject             group          required:group -0.143
# subject             group  valence:required:group  0.006
# subject  valence:required           valence:group -0.190
# subject  valence:required          required:group -0.219
# subject  valence:required  valence:required:group  0.090
# subject     valence:group          required:group  0.154
# subject     valence:group  valence:required:group -0.211
# subject    required:group  valence:required:group -0.045
#
# Fixed effects:
#                         Estimate  2.5_ci  97.5_ci     SE     OR  OR_2.5_ci  \
# (Intercept)               -0.756  -1.318   -0.195  0.287  0.469      0.268
# valence                    1.058   0.776    1.341  0.144  2.882      2.172
# required                   1.099   0.882    1.316  0.111  3.001      2.417
# group                      0.086  -0.172    0.343  0.131  1.089      0.842
# site                      -0.005  -0.110    0.100  0.053  0.995      0.896
# cis                       -0.170  -0.320   -0.020  0.077  0.843      0.726
# dep                        0.029  -0.222    0.281  0.128  1.030      0.801
# valence:required          -0.035  -0.355    0.285  0.163  0.965      0.701
# valence:group             -0.147  -0.571    0.276  0.216  0.863      0.565
# required:group             0.142  -0.173    0.457  0.161  1.152      0.841
# valence:required:group     0.089  -0.402    0.580  0.250  1.093      0.669
#
#                         OR_97.5_ci   Prob  Prob_2.5_ci  Prob_97.5_ci  Z-stat  \
# (Intercept)                  0.823  0.319        0.211         0.451  -2.640
# valence                      3.824  0.742        0.685         0.793   7.337
# required                     3.727  0.750        0.707         0.788   9.943
# group                        1.409  0.521        0.457         0.585   0.653
# site                         1.105  0.499        0.473         0.525  -0.094
# cis                          0.980  0.458        0.421         0.495  -2.223
# dep                          1.324  0.507        0.445         0.570   0.228
# valence:required             1.330  0.491        0.412         0.571  -0.216
# valence:group                1.318  0.463        0.361         0.569  -0.682
# required:group               1.579  0.535        0.457         0.612   0.883
# valence:required:group       1.785  0.522        0.401         0.641   0.354
#
#                         P-val  Sig
# (Intercept)             0.008   **
# valence                 0.000  ***
# required                0.000  ***
# group                   0.514
# site                    0.925
# cis                     0.026    *
# dep                     0.820
# valence:required        0.829
# valence:group           0.495
# required:group          0.377
# valence:required:group  0.723

# %% [markdown]
# Over all sessions separately:
# - significant main effect of required action, indicating that participants learned the task
# - significant main effect of valence, indicating that participants’ choices were affected by motivational biases, with less Go responses to Win cues than Avoid cues
# - no group effects...
# - at week 2 choice is related to site
# - at week 6 choise is related to cis

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------
# Logistic MLE using data over all sessions:
# --

# %%
taskids = data['subids']
rctids = dfRCT['identifier_n']
group = dfRCT['group']
group_matched = panda.match_ids(group, taskids, rctids)
group_all = np.hstack((np.zeros(np.sum(data['sess']==1)), group_matched[data['sess']==2], group_matched[data['sess']==3]))
subjects = np.full([len(data['subids'])], np.nan)
for i, subid in enumerate(np.unique(data['subids'])):
    subjects[np.where(data['subids'] == subid)] = (i + 1)
    
stratification_variables = dfRCT[['_site_n','cistotal_cat','depr_dur_2years']]
stratification_variables_matched = pd.DataFrame()
for c in stratification_variables.columns:
    stratification_variables_matched[c] = panda.match_ids(stratification_variables[c], taskids, rctids)

# %%
go = data['a'].T.flatten()
go[go==2] = 0
go[go==3] = np.nan
required_go = np.zeros_like(go)
required_go[(data['stimuli'].T.flatten() == 1)  | (data['stimuli'].T.flatten() == 2)] = 1
valence = np.zeros_like(go)
valence[(data['stimuli'].T.flatten() == 1)  | (data['stimuli'].T.flatten() == 3)] = 1
subjects = np.repeat(subjects,96)
session = np.repeat(data['sess'],96)
group_all = (np.repeat(group_all,96) == 2).astype(int)
site = np.repeat(stratification_variables_matched['_site_n'],96)
cis = np.repeat(stratification_variables_matched['cistotal_cat'],96)
dep = np.repeat(stratification_variables_matched['depr_dur_2years'],96)
df = pd.DataFrame({'subject': subjects, 'choice': go, 'required': required_go, \
                   'valence': valence, 'group': group_all, 'session': session, \
                   'site': site,'cis': cis, 'dep': dep})
df = df.dropna()

# %%
df['choice'][(df['group']==1)&(df['valence']==1)].mean(), df['choice'][(df['group']==0)&(df['valence']==1)].mean()
# Out:
# (0.581906524757057, 0.555368889788483)

# %%
df['choice'][(df['group']==1)&(df['valence']==0)].mean(), df['choice'][(df['group']==0)&(df['valence']==0)].mean()
# Out:
# (0.4284282003372374, 0.3932557302292092)

# %%
df['choice'][(df['valence']==1)].mean(), df['choice'][(df['valence']==0)].mean()
# Out:
# (0.5634443427444906, 0.4039838200747835)

# %%
model = Lmer("choice  ~ valence * required * group * session + site + cis + dep + (valence * required * session + 1|subject)",
             data=df, family = 'binomial')

print(model.fit())
# Out:
# [1] "failure to converge in 10000 evaluations"
# [2] " \n"
#
# Model failed to converge with max|grad| = 2.18099 (tol = 0.002, component 1)
#
# Formula: choice~valence*required*group*session+site+cis+dep+(valence*required*session+1|subject)
#
# Family: binomial	 Inference: parametric
#
# Number of observations: 142956	 Groups: {'subject': 626.0}
#
# Log-likelihood: -77186.005 	 AIC: 154482.011
#
# Random effects:
#
#                              Name    Var    Std
# subject               (Intercept)  2.310  1.520
# subject                   valence  6.170  2.484
# subject                  required  1.812  1.346
# subject                   session  0.448  0.669
# subject          valence:required  9.168  3.028
# subject           valence:session  1.551  1.245
# subject          required:session  0.444  0.666
# subject  valence:required:session  2.400  1.549
#
#                       IV1                       IV2   Corr
# subject       (Intercept)                   valence -0.012
# subject       (Intercept)                  required -0.314
# subject       (Intercept)                   session -0.766
# subject       (Intercept)          valence:required  0.059
# subject       (Intercept)           valence:session -0.088
# subject       (Intercept)          required:session  0.238
# subject       (Intercept)  valence:required:session  0.037
# subject           valence                  required  0.236
# subject           valence                   session -0.031
# subject           valence          valence:required -0.610
# subject           valence           valence:session -0.839
# subject           valence          required:session -0.105
# subject           valence  valence:required:session  0.554
# subject          required                   session  0.297
# subject          required          valence:required -0.324
# subject          required           valence:session -0.180
# subject          required          required:session -0.712
# subject          required  valence:required:session  0.268
# subject           session          valence:required -0.036
# subject           session           valence:session  0.026
# subject           session          required:session -0.334
# subject           session  valence:required:session -0.002
# subject  valence:required           valence:session  0.576
# subject  valence:required          required:session  0.264
# subject  valence:required  valence:required:session -0.901
# subject   valence:session          required:session  0.176
# subject   valence:session  valence:required:session -0.659
# subject  required:session  valence:required:session -0.261
#
# Fixed effects:
#
#                                 Estimate  2.5_ci  97.5_ci     SE     OR  \
# (Intercept)                       -0.601  -0.977   -0.225  0.192  0.548
# valence                            0.701   0.455    0.948  0.126  2.016
# required                           0.554   0.395    0.713  0.081  1.740
# group                              0.267  -0.006    0.541  0.139  1.306
# session                           -0.063  -0.150    0.024  0.044  0.939
# site                              -0.064  -0.131    0.002  0.034  0.938
# cis                               -0.082  -0.182    0.018  0.051  0.921
# dep                                0.010  -0.157    0.177  0.085  1.010
# valence:required                   0.006  -0.305    0.318  0.159  1.006
# valence:group                      0.803   0.376    1.230  0.218  2.232
# required:group                    -0.148  -0.512    0.216  0.186  0.862
# valence:session                    0.129  -0.021    0.279  0.076  1.138
# required:session                   0.177   0.080    0.274  0.050  1.194
# group:session                     -0.054  -0.200    0.092  0.075  0.948
# valence:required:group            -0.790  -1.385   -0.194  0.304  0.454
# valence:required:session          -0.045  -0.230    0.141  0.095  0.956
# valence:group:session             -0.397  -0.638   -0.156  0.123  0.672
# required:group:session             0.081  -0.099    0.261  0.092  1.084
# valence:required:group:session     0.355   0.046    0.664  0.158  1.426
#
#                                 OR_2.5_ci  OR_97.5_ci   Prob  Prob_2.5_ci  \
# (Intercept)                         0.377       0.798  0.354        0.274
# valence                             1.576       2.580  0.668        0.612
# required                            1.484       2.041  0.635        0.597
# group                               0.994       1.717  0.566        0.498
# session                             0.861       1.024  0.484        0.463
# site                                0.878       1.002  0.484        0.467
# cis                                 0.834       1.018  0.480        0.455
# dep                                 0.855       1.194  0.503        0.461
# valence:required                    0.737       1.374  0.502        0.424
# valence:group                       1.457       3.420  0.691        0.593
# required:group                      0.599       1.241  0.463        0.375
# valence:session                     0.980       1.322  0.532        0.495
# required:session                    1.083       1.315  0.544        0.520
# group:session                       0.819       1.097  0.487        0.450
# valence:required:group              0.250       0.823  0.312        0.200
# valence:required:session            0.794       1.151  0.489        0.443
# valence:group:session               0.528       0.856  0.402        0.346
# required:group:session              0.906       1.298  0.520        0.475
# valence:required:group:session      1.047       1.943  0.588        0.512
#
#                                 Prob_97.5_ci  Z-stat  P-val  Sig
# (Intercept)                            0.444  -3.137  0.002   **
# valence                                0.721   5.576  0.000  ***
# required                               0.671   6.818  0.000  ***
# group                                  0.632   1.915  0.056    .
# session                                0.506  -1.424  0.155
# site                                   0.500  -1.903  0.057    .
# cis                                    0.505  -1.607  0.108
# dep                                    0.544   0.120  0.905
# valence:required                       0.579   0.040  0.968
# valence:group                          0.774   3.688  0.000  ***
# required:group                         0.554  -0.797  0.426
# valence:session                        0.569   1.690  0.091    .
# required:session                       0.568   3.571  0.000  ***
# group:session                          0.523  -0.722  0.470
# valence:required:group                 0.452  -2.600  0.009   **
# valence:required:session               0.535  -0.475  0.635
# valence:group:session                  0.461  -3.229  0.001   **
# required:group:session                 0.565   0.884  0.377
# valence:required:group:session         0.660   2.254  0.024    *

# %%
print(model.summary()[['Estimate', '2.5_ci' ,'97.5_ci', 'Z-stat','P-val']].to_latex())
# Out:
# Formula: choice~valence*required*group*session+site+cis+dep+(valence*required*session+1|subject)
#
# Family: binomial	 Inference: parametric
#
# Number of observations: 142956	 Groups: {'subject': 626.0}
#
# Log-likelihood: -77186.005 	 AIC: 154482.011
#
# Random effects:
#
#                              Name    Var    Std
# subject               (Intercept)  2.310  1.520
# subject                   valence  6.170  2.484
# subject                  required  1.812  1.346
# subject                   session  0.448  0.669
# subject          valence:required  9.168  3.028
# subject           valence:session  1.551  1.245
# subject          required:session  0.444  0.666
# subject  valence:required:session  2.400  1.549
#
#                       IV1                       IV2   Corr
# subject       (Intercept)                   valence -0.012
# subject       (Intercept)                  required -0.314
# subject       (Intercept)                   session -0.766
# subject       (Intercept)          valence:required  0.059
# subject       (Intercept)           valence:session -0.088
# subject       (Intercept)          required:session  0.238
# subject       (Intercept)  valence:required:session  0.037
# subject           valence                  required  0.236
# subject           valence                   session -0.031
# subject           valence          valence:required -0.610
# subject           valence           valence:session -0.839
# subject           valence          required:session -0.105
# subject           valence  valence:required:session  0.554
# subject          required                   session  0.297
# subject          required          valence:required -0.324
# subject          required           valence:session -0.180
# subject          required          required:session -0.712
# subject          required  valence:required:session  0.268
# subject           session          valence:required -0.036
# subject           session           valence:session  0.026
# subject           session          required:session -0.334
# subject           session  valence:required:session -0.002
# subject  valence:required           valence:session  0.576
# subject  valence:required          required:session  0.264
# subject  valence:required  valence:required:session -0.901
# subject   valence:session          required:session  0.176
# subject   valence:session  valence:required:session -0.659
# subject  required:session  valence:required:session -0.261
#
# Fixed effects:
#
# \begin{tabular}{lrrrrr}
# \toprule
# {} &  Estimate &  2.5\_ci &  97.5\_ci &  Z-stat &  P-val \\
# \midrule
# (Intercept)                    &    -0.601 &  -0.977 &   -0.225 &  -3.137 &  0.002 \\
# valence                        &     0.701 &   0.455 &    0.948 &   5.576 &  0.000 \\
# required                       &     0.554 &   0.395 &    0.713 &   6.818 &  0.000 \\
# group                          &     0.267 &  -0.006 &    0.541 &   1.915 &  0.056 \\
# session                        &    -0.063 &  -0.150 &    0.024 &  -1.424 &  0.155 \\
# site                           &    -0.064 &  -0.131 &    0.002 &  -1.903 &  0.057 \\
# cis                            &    -0.082 &  -0.182 &    0.018 &  -1.607 &  0.108 \\
# dep                            &     0.010 &  -0.157 &    0.177 &   0.120 &  0.905 \\
# valence:required               &     0.006 &  -0.305 &    0.318 &   0.040 &  0.968 \\
# valence:group                  &     0.803 &   0.376 &    1.230 &   3.688 &  0.000 \\
# required:group                 &    -0.148 &  -0.512 &    0.216 &  -0.797 &  0.426 \\
# valence:session                &     0.129 &  -0.021 &    0.279 &   1.690 &  0.091 \\
# required:session               &     0.177 &   0.080 &    0.274 &   3.571 &  0.000 \\
# group:session                  &    -0.054 &  -0.200 &    0.092 &  -0.722 &  0.470 \\
# valence:required:group         &    -0.790 &  -1.385 &   -0.194 &  -2.600 &  0.009 \\
# valence:required:session       &    -0.045 &  -0.230 &    0.141 &  -0.475 &  0.635 \\
# valence:group:session          &    -0.397 &  -0.638 &   -0.156 &  -3.229 &  0.001 \\
# required:group:session         &     0.081 &  -0.099 &    0.261 &   0.884 &  0.377 \\
# valence:required:group:session &     0.355 &   0.046 &    0.664 &   2.254 &  0.024 \\
# \bottomrule
# \end{tabular}
# <ipython-input-29-590a2a37b3c0>:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(model.summary()[['Estimate', '2.5_ci' ,'97.5_ci', 'Z-stat','P-val']].to_latex())

# %%
print(df['choice'][df['valence']==1].mean(),df['choice'][df['valence']==0].mean())
print(df['choice'][df['required']==1].mean(),df['choice'][df['required']==0].mean())
print(df['choice'][df['group']==1].mean(),df['choice'][df['group']==0].mean())
# Out:
# 0.5634443427444906 0.4039838200747835
# 0.5667747413926201 0.4001589758607706
# 0.5045806259040709 0.47382875768336974

# %%
model.summary()
# Out:
# Formula: choice~valence*required*group*session+site+cis+dep+(valence*required*session+1|subject)
#
# Family: binomial	 Inference: parametric
#
# Number of observations: 142956	 Groups: {'subject': 626.0}
#
# Log-likelihood: -77186.005 	 AIC: 154482.011
#
# Random effects:
#
#                              Name    Var    Std
# subject               (Intercept)  2.310  1.520
# subject                   valence  6.170  2.484
# subject                  required  1.812  1.346
# subject                   session  0.448  0.669
# subject          valence:required  9.168  3.028
# subject           valence:session  1.551  1.245
# subject          required:session  0.444  0.666
# subject  valence:required:session  2.400  1.549
#
#                       IV1                       IV2   Corr
# subject       (Intercept)                   valence -0.012
# subject       (Intercept)                  required -0.314
# subject       (Intercept)                   session -0.766
# subject       (Intercept)          valence:required  0.059
# subject       (Intercept)           valence:session -0.088
# subject       (Intercept)          required:session  0.238
# subject       (Intercept)  valence:required:session  0.037
# subject           valence                  required  0.236
# subject           valence                   session -0.031
# subject           valence          valence:required -0.610
# subject           valence           valence:session -0.839
# subject           valence          required:session -0.105
# subject           valence  valence:required:session  0.554
# subject          required                   session  0.297
# subject          required          valence:required -0.324
# subject          required           valence:session -0.180
# subject          required          required:session -0.712
# subject          required  valence:required:session  0.268
# subject           session          valence:required -0.036
# subject           session           valence:session  0.026
# subject           session          required:session -0.334
# subject           session  valence:required:session -0.002
# subject  valence:required           valence:session  0.576
# subject  valence:required          required:session  0.264
# subject  valence:required  valence:required:session -0.901
# subject   valence:session          required:session  0.176
# subject   valence:session  valence:required:session -0.659
# subject  required:session  valence:required:session -0.261
#
# Fixed effects:
#                                 Estimate  2.5_ci  97.5_ci     SE     OR  \
# (Intercept)                       -0.601  -0.977   -0.225  0.192  0.548
# valence                            0.701   0.455    0.948  0.126  2.016
# required                           0.554   0.395    0.713  0.081  1.740
# group                              0.267  -0.006    0.541  0.139  1.306
# session                           -0.063  -0.150    0.024  0.044  0.939
# site                              -0.064  -0.131    0.002  0.034  0.938
# cis                               -0.082  -0.182    0.018  0.051  0.921
# dep                                0.010  -0.157    0.177  0.085  1.010
# valence:required                   0.006  -0.305    0.318  0.159  1.006
# valence:group                      0.803   0.376    1.230  0.218  2.232
# required:group                    -0.148  -0.512    0.216  0.186  0.862
# valence:session                    0.129  -0.021    0.279  0.076  1.138
# required:session                   0.177   0.080    0.274  0.050  1.194
# group:session                     -0.054  -0.200    0.092  0.075  0.948
# valence:required:group            -0.790  -1.385   -0.194  0.304  0.454
# valence:required:session          -0.045  -0.230    0.141  0.095  0.956
# valence:group:session             -0.397  -0.638   -0.156  0.123  0.672
# required:group:session             0.081  -0.099    0.261  0.092  1.084
# valence:required:group:session     0.355   0.046    0.664  0.158  1.426
#
#                                 OR_2.5_ci  OR_97.5_ci   Prob  Prob_2.5_ci  \
# (Intercept)                         0.377       0.798  0.354        0.274
# valence                             1.576       2.580  0.668        0.612
# required                            1.484       2.041  0.635        0.597
# group                               0.994       1.717  0.566        0.498
# session                             0.861       1.024  0.484        0.463
# site                                0.878       1.002  0.484        0.467
# cis                                 0.834       1.018  0.480        0.455
# dep                                 0.855       1.194  0.503        0.461
# valence:required                    0.737       1.374  0.502        0.424
# valence:group                       1.457       3.420  0.691        0.593
# required:group                      0.599       1.241  0.463        0.375
# valence:session                     0.980       1.322  0.532        0.495
# required:session                    1.083       1.315  0.544        0.520
# group:session                       0.819       1.097  0.487        0.450
# valence:required:group              0.250       0.823  0.312        0.200
# valence:required:session            0.794       1.151  0.489        0.443
# valence:group:session               0.528       0.856  0.402        0.346
# required:group:session              0.906       1.298  0.520        0.475
# valence:required:group:session      1.047       1.943  0.588        0.512
#
#                                 Prob_97.5_ci  Z-stat  P-val  Sig
# (Intercept)                            0.444  -3.137  0.002   **
# valence                                0.721   5.576  0.000  ***
# required                               0.671   6.818  0.000  ***
# group                                  0.632   1.915  0.056    .
# session                                0.506  -1.424  0.155
# site                                   0.500  -1.903  0.057    .
# cis                                    0.505  -1.607  0.108
# dep                                    0.544   0.120  0.905
# valence:required                       0.579   0.040  0.968
# valence:group                          0.774   3.688  0.000  ***
# required:group                         0.554  -0.797  0.426
# valence:session                        0.569   1.690  0.091    .
# required:session                       0.568   3.571  0.000  ***
# group:session                          0.523  -0.722  0.470
# valence:required:group                 0.452  -2.600  0.009   **
# valence:required:session               0.535  -0.475  0.635
# valence:group:session                  0.461  -3.229  0.001   **
# required:group:session                 0.565   0.884  0.377
# valence:required:group:session         0.660   2.254  0.024    *

# %% [markdown]
# All data over three session [1,2,3]:
#
# - significant main effect of required action, indicating that participants learned the task
# - significant main effect of valence, indicating that participants’ choices were affected by motivational biases, with more Go responses to Win cues than Avoid cues
# - significant interaction of group and valence, indicating that the main modulatory effect of cue valence on ‘Go’ responding, i.e. the motivational bias, was modulated by sertraline
# - significant interaction of required action and session, indicating that time modulated how participants learned the task
# - significant valence x group × session interaction effect, indicating that the main modulatory effect of cue valence on ‘Go’ responding, i.e. the motivational bias, was modulated by sertraline over time.
# - significant valence x required action × session interaction effect, indicating that the motivational biases differ in size for Go vs. NoGo cues depending on the session
# - significant valence x required action × session x group interaction effect

# %%
# looking only at session 1 and 2
model = Lmer("choice  ~ valence * required * group * session + site + cis + dep + (valence * required * session + 1|subject)",
             data=df[(df['session']==1)|(df['session']==2)], family = 'binomial')

print(model.fit())
# Out:
# [1] "failure to converge in 10000 evaluations"
# [2] " \n"
#
# Model failed to converge with max|grad| = 0.0179719 (tol = 0.002, component 1)
#
# Formula: choice~valence*required*group*session+site+cis+dep+(valence*required*session+1|subject)
#
# Family: binomial	 Inference: parametric
#
# Number of observations: 100211	 Groups: {'subject': 625.0}
#
# Log-likelihood: -53196.861 	 AIC: 106495.721
#
# Random effects:
#
#                              Name     Var    Std
# subject               (Intercept)   4.028  2.007
# subject                   valence  10.856  3.295
# subject                  required   3.576  1.891
# subject                   session   1.267  1.125
# subject          valence:required  19.116  4.372
# subject           valence:session   4.586  2.142
# subject          required:session   1.419  1.191
# subject  valence:required:session   8.360  2.891
#
#                       IV1                       IV2   Corr
# subject       (Intercept)                   valence -0.123
# subject       (Intercept)                  required -0.468
# subject       (Intercept)                   session -0.865
# subject       (Intercept)          valence:required  0.132
# subject       (Intercept)           valence:session  0.100
# subject       (Intercept)          required:session  0.454
# subject       (Intercept)  valence:required:session -0.091
# subject           valence                  required  0.277
# subject           valence                   session  0.080
# subject           valence          valence:required -0.685
# subject           valence           valence:session -0.896
# subject           valence          required:session -0.184
# subject           valence  valence:required:session  0.652
# subject          required                   session  0.438
# subject          required          valence:required -0.376
# subject          required           valence:session -0.275
# subject          required          required:session -0.861
# subject          required  valence:required:session  0.348
# subject           session          valence:required -0.106
# subject           session           valence:session -0.103
# subject           session          required:session -0.476
# subject           session  valence:required:session  0.093
# subject  valence:required           valence:session  0.661
# subject  valence:required          required:session  0.323
# subject  valence:required  valence:required:session -0.943
# subject   valence:session          required:session  0.262
# subject   valence:session  valence:required:session -0.711
# subject  required:session  valence:required:session -0.326
#
# Fixed effects:
#
#                           Estimate  2.5_ci  97.5_ci     SE     OR  OR_2.5_ci  \
# (Intercept)                 -0.607  -1.019   -0.195  0.210  0.545      0.361
# valence                      0.638   0.294    0.982  0.176  1.893      1.341
# required                     0.419   0.190    0.649  0.117  1.521      1.209
# group                        0.180  -0.010    0.370  0.097  1.198      0.990
# session                     -0.105  -0.253    0.043  0.075  0.901      0.777
# site                        -0.067  -0.137    0.003  0.036  0.935      0.872
# cis                         -0.068  -0.172    0.037  0.053  0.934      0.842
# dep                          0.013  -0.162    0.189  0.090  1.013      0.850
# valence:required            -0.079  -0.532    0.373  0.231  0.924      0.588
# valence:group               -0.029  -0.371    0.314  0.175  0.972      0.690
# required:group              -0.081  -0.300    0.138  0.112  0.922      0.741
# valence:session              0.195  -0.067    0.456  0.134  1.215      0.935
# required:session             0.302   0.131    0.473  0.087  1.353      1.140
# valence:required:group      -0.065  -0.488    0.358  0.216  0.937      0.614
# valence:required:session     0.040  -0.301    0.381  0.174  1.041      0.740
#
#                           OR_97.5_ci   Prob  Prob_2.5_ci  Prob_97.5_ci  \
# (Intercept)                    0.823  0.353        0.265         0.451
# valence                        2.671  0.654        0.573         0.728
# required                       1.914  0.603        0.547         0.657
# group                          1.448  0.545        0.498         0.592
# session                        1.044  0.474        0.437         0.511
# site                           1.003  0.483        0.466         0.501
# cis                            1.037  0.483        0.457         0.509
# dep                            1.208  0.503        0.459         0.547
# valence:required               1.452  0.480        0.370         0.592
# valence:group                  1.369  0.493        0.408         0.578
# required:group                 1.148  0.480        0.426         0.534
# valence:session                1.578  0.549        0.483         0.612
# required:session               1.604  0.575        0.533         0.616
# valence:required:group         1.430  0.484        0.380         0.588
# valence:required:session       1.463  0.510        0.425         0.594
#
#                           Z-stat  P-val  Sig
# (Intercept)               -2.889  0.004   **
# valence                    3.631  0.000  ***
# required                   3.577  0.000  ***
# group                      1.860  0.063    .
# session                   -1.389  0.165
# site                      -1.882  0.060    .
# cis                       -1.273  0.203
# dep                        0.149  0.882
# valence:required          -0.343  0.731
# valence:group             -0.164  0.870
# required:group            -0.724  0.469
# valence:session            1.458  0.145
# required:session           3.469  0.001  ***
# valence:required:group    -0.303  0.762
# valence:required:session   0.230  0.818

# %%
# looking only at session 1 and 3
model = Lmer("choice  ~ valence * required * group * session + site + cis + dep + (valence * required * session + 1|subject)",
             data=df[(df['session']==1)|(df['session']==3)], family = 'binomial')

print(model.fit())
# Out:
# [1] "failure to converge in 10000 evaluations"
# [2] " \n"
#
# Model failed to converge with max|grad| = 0.0338642 (tol = 0.002, component 1)
#
# Formula: choice~valence*required*group*session+site+cis+dep+(valence*required*session+1|subject)
#
# Family: binomial	 Inference: parametric
#
# Number of observations: 96472	 Groups: {'subject': 626.0}
#
# Log-likelihood: -50598.104 	 AIC: 101298.208
#
# Random effects:
#
#                              Name    Var    Std
# subject               (Intercept)  2.426  1.558
# subject                   valence  5.921  2.433
# subject                  required  1.820  1.349
# subject                   session  0.404  0.635
# subject          valence:required  8.525  2.920
# subject           valence:session  1.344  1.159
# subject          required:session  0.439  0.663
# subject  valence:required:session  1.960  1.400
#
#                       IV1                       IV2   Corr
# subject       (Intercept)                   valence -0.097
# subject       (Intercept)                  required -0.382
# subject       (Intercept)                   session -0.735
# subject       (Intercept)          valence:required  0.133
# subject       (Intercept)           valence:session -0.001
# subject       (Intercept)          required:session  0.293
# subject       (Intercept)  valence:required:session -0.024
# subject           valence                  required  0.284
# subject           valence                   session  0.061
# subject           valence          valence:required -0.633
# subject           valence           valence:session -0.790
# subject           valence          required:session -0.133
# subject           valence  valence:required:session  0.548
# subject          required                   session  0.329
# subject          required          valence:required -0.365
# subject          required           valence:session -0.188
# subject          required          required:session -0.637
# subject          required  valence:required:session  0.275
# subject           session          valence:required -0.132
# subject           session           valence:session -0.083
# subject           session          required:session -0.418
# subject           session  valence:required:session  0.102
# subject  valence:required           valence:session  0.543
# subject  valence:required          required:session  0.279
# subject  valence:required  valence:required:session -0.841
# subject   valence:session          required:session  0.187
# subject   valence:session  valence:required:session -0.662
# subject  required:session  valence:required:session -0.298
#
# Fixed effects:
#
#                           Estimate  2.5_ci  97.5_ci     SE     OR  OR_2.5_ci  \
# (Intercept)                 -0.652  -1.048   -0.255  0.202  0.521      0.351
# valence                      0.729   0.484    0.974  0.125  2.073      1.622
# required                     0.522   0.360    0.685  0.083  1.686      1.433
# group                        0.118  -0.115    0.350  0.119  1.125      0.892
# session                     -0.065  -0.152    0.022  0.044  0.937      0.859
# site                        -0.062  -0.134    0.010  0.037  0.940      0.875
# cis                         -0.099  -0.207    0.010  0.055  0.906      0.813
# dep                          0.065  -0.115    0.245  0.092  1.067      0.892
# valence:required            -0.039  -0.343    0.265  0.155  0.962      0.710
# valence:group               -0.182  -0.586    0.222  0.206  0.834      0.557
# required:group               0.078  -0.201    0.358  0.143  1.081      0.818
# valence:session              0.103  -0.048    0.254  0.077  1.109      0.954
# required:session             0.194   0.092    0.296  0.052  1.214      1.096
# valence:required:group       0.100  -0.378    0.578  0.244  1.105      0.685
# valence:required:session     0.001  -0.183    0.185  0.094  1.001      0.832
#
#                           OR_97.5_ci   Prob  Prob_2.5_ci  Prob_97.5_ci  \
# (Intercept)                    0.775  0.343        0.260         0.437
# valence                        2.649  0.675        0.619         0.726
# required                       1.983  0.628        0.589         0.665
# group                          1.420  0.529        0.471         0.587
# session                        1.022  0.484        0.462         0.505
# site                           1.010  0.485        0.467         0.502
# cis                            1.010  0.475        0.448         0.502
# dep                            1.278  0.516        0.471         0.561
# valence:required               1.303  0.490        0.415         0.566
# valence:group                  1.248  0.455        0.358         0.555
# required:group                 1.430  0.520        0.450         0.588
# valence:session                1.289  0.526        0.488         0.563
# required:session               1.345  0.548        0.523         0.574
# valence:required:group         1.782  0.525        0.407         0.641
# valence:required:session       1.203  0.500        0.454         0.546
#
#                           Z-stat  P-val  Sig
# (Intercept)               -3.223  0.001   **
# valence                    5.828  0.000  ***
# required                   6.298  0.000  ***
# group                      0.993  0.321
# session                   -1.472  0.141
# site                      -1.696  0.090    .
# cis                       -1.780  0.075    .
# dep                        0.711  0.477
# valence:required          -0.253  0.801
# valence:group             -0.883  0.377
# required:group             0.549  0.583
# valence:session            1.342  0.179
# required:session           3.721  0.000  ***
# valence:required:group     0.409  0.682
# valence:required:session   0.007  0.994

# %%
# time as [0,1,1] repetition of task
df['repetition'] = np.hstack((np.tile(0, sum(df['session'] == 1)),np.tile(1, sum(df['session'] == 2)),np.tile(1, sum(df['session'] == 3))))
model = Lmer("choice  ~ valence * required * group * repetition + site + cis + dep + (valence * required * repetition + 1|subject)",
             data=df, family = 'binomial')

print(model.fit())
# Out:
# [1] "failure to converge in 10000 evaluations"
# [2] " \n"
#
# Model failed to converge with max|grad| = 0.555447 (tol = 0.002, component 1)
#
# Formula: choice~valence*required*group*repetition+site+cis+dep+(valence*required*repetition+1|subject)
#
# Family: binomial	 Inference: parametric
#
# Number of observations: 142956	 Groups: {'subject': 626.0}
#
# Log-likelihood: -77713.028 	 AIC: 155528.056
#
# Random effects:
#
#                                 Name    Var    Std
# subject                  (Intercept)  1.377  1.173
# subject                      valence  2.811  1.677
# subject                     required  1.121  1.059
# subject                   repetition  1.121  1.059
# subject             valence:required  3.635  1.906
# subject           valence:repetition  3.351  1.831
# subject          required:repetition  1.097  1.047
# subject  valence:required:repetition  5.724  2.393
#
#                          IV1                          IV2   Corr
# subject          (Intercept)                      valence -0.169
# subject          (Intercept)                     required -0.323
# subject          (Intercept)                   repetition -0.561
# subject          (Intercept)             valence:required  0.178
# subject          (Intercept)           valence:repetition -0.022
# subject          (Intercept)          required:repetition  0.261
# subject          (Intercept)  valence:required:repetition -0.018
# subject              valence                     required  0.320
# subject              valence                   repetition  0.021
# subject              valence             valence:required -0.584
# subject              valence           valence:repetition -0.607
# subject              valence          required:repetition -0.065
# subject              valence  valence:required:repetition  0.417
# subject             required                   repetition  0.229
# subject             required             valence:required -0.324
# subject             required           valence:repetition -0.207
# subject             required          required:repetition -0.420
# subject             required  valence:required:repetition  0.235
# subject           repetition             valence:required -0.115
# subject           repetition           valence:repetition -0.061
# subject           repetition          required:repetition -0.425
# subject           repetition  valence:required:repetition  0.079
# subject     valence:required           valence:repetition  0.487
# subject     valence:required          required:repetition  0.286
# subject     valence:required  valence:required:repetition -0.736
# subject   valence:repetition          required:repetition  0.226
# subject   valence:repetition  valence:required:repetition -0.693
# subject  required:repetition  valence:required:repetition -0.329
#
# Fixed effects:
#
#                              Estimate  2.5_ci  97.5_ci     SE     OR  \
# (Intercept)                    -0.690  -1.042   -0.337  0.180  0.502
# valence                         0.822   0.673    0.972  0.076  2.275
# required                        0.709   0.605    0.813  0.053  2.032
# group                           0.135  -0.031    0.300  0.084  1.144
# repetition                     -0.059  -0.192    0.074  0.068  0.943
# site                           -0.056  -0.122    0.009  0.033  0.945
# cis                            -0.084  -0.183    0.014  0.050  0.919
# dep                             0.013  -0.152    0.178  0.084  1.013
# valence:required               -0.025  -0.206    0.155  0.092  0.975
# valence:group                  -0.147  -0.408    0.114  0.133  0.863
# required:group                 -0.016  -0.203    0.171  0.095  0.984
# valence:repetition              0.193  -0.024    0.410  0.111  1.213
# required:repetition             0.308   0.158    0.459  0.077  1.361
# valence:required:group          0.053  -0.254    0.361  0.157  1.055
# valence:required:repetition    -0.119  -0.397    0.160  0.142  0.888
#
#                              OR_2.5_ci  OR_97.5_ci   Prob  Prob_2.5_ci  \
# (Intercept)                      0.353       0.714  0.334        0.261
# valence                          1.960       2.642  0.695        0.662
# required                         1.831       2.254  0.670        0.647
# group                            0.970       1.350  0.534        0.492
# repetition                       0.825       1.077  0.485        0.452
# site                             0.885       1.009  0.486        0.470
# cis                              0.833       1.014  0.479        0.454
# dep                              0.859       1.194  0.503        0.462
# valence:required                 0.814       1.168  0.494        0.449
# valence:group                    0.665       1.121  0.463        0.399
# required:group                   0.816       1.187  0.496        0.449
# valence:repetition               0.976       1.507  0.548        0.494
# required:repetition              1.171       1.582  0.576        0.539
# valence:required:group           0.776       1.435  0.513        0.437
# valence:required:repetition      0.672       1.174  0.470        0.402
#
#                              Prob_97.5_ci  Z-stat  P-val  Sig
# (Intercept)                         0.417  -3.833  0.000  ***
# valence                             0.725  10.789  0.000  ***
# required                            0.693  13.353  0.000  ***
# group                               0.574   1.594  0.111
# repetition                          0.519  -0.869  0.385
# site                                0.502  -1.691  0.091    .
# cis                                 0.503  -1.683  0.092    .
# dep                                 0.544   0.152  0.879
# valence:required                    0.539  -0.276  0.782
# valence:group                       0.528  -1.105  0.269
# required:group                      0.543  -0.165  0.869
# valence:repetition                  0.601   1.743  0.081    .
# required:repetition                 0.613   4.023  0.000  ***
# valence:required:group              0.589   0.340  0.733
# valence:required:repetition         0.540  -0.834  0.404
