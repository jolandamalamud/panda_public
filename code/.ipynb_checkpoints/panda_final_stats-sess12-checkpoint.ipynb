# %%
import numpy as np
import pandas as pd
from plotting import Plotting
from loading_preparing_data import Panda
import statsmodels.formula.api as smf
import seaborn as sns, matplotlib.pyplot as plt

# %%
filepath = '/Users/jolandamalamud/phd/projects/gng_panda_antler/gng_panda/data/'
panda = Panda(filepath)
disp = Plotting()
# load raw task data
D = panda.load_data()
# prep action choices to plot
data_all = panda.extract_data(D)
data = panda.extract_data(D[((data_all['sess']==1)|(data_all['sess']==2))])
#data = data_all
# load modelling data
modelling = panda.load_modelling_results('/modelling_results/final_results/sess12/', ['ll2b2a2epxb', 'llb'])
random_baseline_model = panda.load_modelling_results('/modelling_results/final_results/sess12/', ['llb'])
# load rct data
dfRCT = panda.load_rctdata()

# %%
# define all variables of interest
parameter_labels = ['rew_se', 'loss_se', 'rew_LR', 'loss_LR', 'app_Pav', 'av_Pav', 'noise', 'bias', \
                    'rbias']
gng_columns = parameter_labels + ['exclusion', 'goprobtot', 'gopro_g2w', 'gopro_g2a', 'gopro_ng2w', \
                              'gopro_ng2a', 'acctot', 'acc_g2w', 'acc_g2a', 'acc_ng2w', 'acc_ng2a','iL']

gng_data = np.vstack((modelling['emmap'], random_baseline_model['emmap'], modelling['excluding'], \
                       np.nanmean(data['a_go'],axis=(0,1)), np.nanmean(data['a_go'],axis=0), \
                       np.nanmean(data['a_correct'],axis=(0,1)), np.nanmean(data['a_correct'],axis=0), \
                       modelling['iL'],))

rct_columns = ['rctid', 'group', 'gad1', 'gad2log', 'gad3log', 'gad4log', 'phq1', 'phq2log', \
               'phq3log', 'phq4log', 'site', 'cis', 'dep', 'age', 'education', 'AD_past', \
               'sex', 'ethnic', 'fin', 'empstat', 'marstat', 'cisscore']

rct_data = dfRCT[['identifier_n', 'group', 'gadtot', 'log_gadtot_2wk', 'log_gadtot_6wk', 'log_gadtot_12wk', \
                  'phqtot', 'log_phqtot_2wk', 'log_phqtot_6wk', 'log_phqtot_12wk', '_site_n', \
                  'cistotal_cat', 'depr_dur_2years', 'age', 'edu3', 'antidepressantsinpast', \
                  'sex', 'ethnic', 'fin3', 'empstat2', 'marstat3', 'cisdepscore']]

# %%
# create dataframe of all variables of interest
df_panda = panda.create_panda_df(data, gng_columns, gng_data, rct_columns, rct_data)
rct_columns.append('gad1log')
number_of_sessions = max(data['sess']).astype(int)
number_of_subjects = len(df_panda)
weeks = [0, 2, 6, 12]

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------
# Exclusion
# --

# %%
# number of excluded subjects due to not performing the task properly
for t in range(1,number_of_sessions+1):
    no_data = df_panda['exclusion' + str(t)].isna()
    ex1 = df_panda['exclusion' + str(t)] == 1
    ex2 = df_panda['acctot' + str(t)] < 0.5
    df_panda.loc[~no_data, 'exclusiontot' + str(t)] = (ex1[~no_data] | ex2[~no_data]).astype(int)
gng_columns.append('exclusiontot')

exclusion = []
for t in range(number_of_sessions):
    exclusion.append(np.nansum(df_panda['exclusiontot' + str(t+1)]))
    print('# of excluded subjects at week ' + str(weeks[t]) + ':\t' + str(exclusion[t]) + \
      ' (' + str(round(exclusion[t]/number_of_subjects*100)) +'%)')
print('total # of excluded subjects:\t\t' + str(sum(exclusion)) + \
      ' (' + str(round(sum(exclusion)/(number_of_sessions*number_of_subjects)*100)) +'%)')
# Out:
# # of excluded subjects at week 0:	354.0 (54%)
# # of excluded subjects at week 2:	253.0 (39%)
# total # of excluded subjects:		607.0 (46%)

# %%
# chi2 pearson test to compare included vs excluded in sertraline vs placebo
tmp = panda.chi2_test(df_panda['exclusiontot2'], df_panda['group'], ['sertraline', 'placebo'])
tmp.insert(0, 'variable', 'exclusion')
display(tmp)
print('N = ' + str(sum(~df_panda['exclusiontot2'].isna() & ~df_panda['group'].isna())) + \
      ', sertraline = ' + str(np.round(df_panda['exclusiontot2'][df_panda['group']==1].mean()*100, 2)) + '%'\
      + ', placebo = ' + str(np.round(df_panda['exclusiontot2'][df_panda['group']==0].mean()*100, 2)) + '%')
# Out:
#       variable  sertraline  placebo    X2      p
# 1.0  exclusion         144      109  9.79  0.002
# 0.0  exclusion         118      157  9.79  0.002
# N = 528, sertraline = 54.96%, placebo = 40.98%

# %%
# is exclusion related to baseline variables?
baseline_continuous =  ['gad1log', 'phq1log', 'age', 'cisscore']
baseline_categorical = ['site', 'cis', 'dep', 'education', \
                        'AD_past','sex', 'ethnic', 'fin', 'empstat', 'marstat']
tab_list = []
for t in range(1,number_of_sessions+1):
    tab = pd.DataFrame()
    for i in baseline_continuous:
        tmp = panda.group_ttest(df_panda[i], df_panda['exclusiontot' + str(t)], ['excluded', 'included'])
        tmp.insert(0, 'variable', i)
        tab = pd.concat((tab, tmp))
    for i in baseline_categorical:
        tmp = panda.chi2_test(df_panda[i], df_panda['exclusiontot'  + str(t)], ['excluded', 'included'])
        tmp.insert(0, 'variable', i)
        tab = pd.concat((tab, tmp))
    tab_list.append(tab)
disp.display_side_by_side(tab_list[0],tab_list[1])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>excluded</th>
#       <th>included</th>
#       <th>t</th>
#       <th>p</th>
#       <th>X2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0.0</th>
#       <td>gad1log</td>
#       <td>0.946</td>
#       <td>0.950</td>
#       <td>-0.207</td>
#       <td>0.836</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>0.0</th>
#       <td>phq1log</td>
#       <td>1.045</td>
#       <td>1.070</td>
#       <td>-1.308</td>
#       <td>0.191</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>0.0</th>
#       <td>age</td>
#       <td>42.895</td>
#       <td>34.481</td>
#       <td>7.501</td>
#       <td>0.000</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>0.0</th>
#       <td>cisscore</td>
#       <td>10.215</td>
#       <td>10.846</td>
#       <td>-1.583</td>
#       <td>0.114</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1.0</th>
#       <td>site</td>
#       <td>147.000</td>
#       <td>110.000</td>
#       <td>NaN</td>
#       <td>0.803</td>
#       <td>0.994</td>
#     </tr>
#     <tr>
#       <th>4.0</th>
#       <td>site</td>
#       <td>76.000</td>
#       <td>51.000</td>
#       <td>NaN</td>
#       <td>0.803</td>
#       <td>0.994</td>
#     </tr>
#     <tr>
#       <th>3.0</th>
#       <td>site</td>
#       <td>66.000</td>
#       <td>57.000</td>
#       <td>NaN</td>
#       <td>0.803</td>
#       <td>0.994</td>
#     </tr>
#     <tr>
#       <th>2.0</th>
#       <td>site</td>
#       <td>65.000</td>
#       <td>48.000</td>
#       <td>NaN</td>
#       <td>0.803</td>
#       <td>0.994</td>
#     </tr>
#     <tr>
#       <th>3.0</th>
#       <td>cis</td>
#       <td>189.000</td>
#       <td>145.000</td>
#       <td>NaN</td>
#       <td>0.600</td>
#       <td>1.022</td>
#     </tr>
#     <tr>
#       <th>2.0</th>
#       <td>cis</td>
#       <td>99.000</td>
#       <td>66.000</td>
#       <td>NaN</td>
#       <td>0.600</td>
#       <td>1.022</td>
#     </tr>
#     <tr>
#       <th>1.0</th>
#       <td>cis</td>
#       <td>65.000</td>
#       <td>55.000</td>
#       <td>NaN</td>
#       <td>0.600</td>
#       <td>1.022</td>
#     </tr>
#     <tr>
#       <th>1.0</th>
#       <td>dep</td>
#       <td>245.000</td>
#       <td>179.000</td>
#       <td>NaN</td>
#       <td>0.674</td>
#       <td>0.177</td>
#     </tr>
#     <tr>
#       <th>2.0</th>
#       <td>dep</td>
#       <td>109.000</td>
#       <td>87.000</td>
#       <td>NaN</td>
#       <td>0.674</td>
#       <td>0.177</td>
#     </tr>
#     <tr>
#       <th>1.0</th>
#       <td>education</td>
#       <td>225.000</td>
#       <td>208.000</td>
#       <td>NaN</td>
#       <td>0.000</td>
#       <td>23.351</td>
#     </tr>
#     <tr>
#       <th>2.0</th>
#       <td>education</td>
#       <td>101.000</td>
#       <td>56.000</td>
#       <td>NaN</td>
#       <td>0.000</td>
#       <td>23.351</td>
#     </tr>
#     <tr>
#       <th>3.0</th>
#       <td>education</td>
#       <td>27.000</td>
#       <td>2.000</td>
#       <td>NaN</td>
#       <td>0.000</td>
#       <td>23.351</td>
#     </tr>
#     <tr>
#       <th>2.0</th>
#       <td>AD_past</td>
#       <td>230.000</td>
#       <td>139.000</td>
#       <td>NaN</td>
#       <td>0.002</td>
#       <td>9.956</td>
#     </tr>
#     <tr>
#       <th>1.0</th>
#       <td>AD_past</td>
#       <td>123.000</td>
#       <td>127.000</td>
#       <td>NaN</td>
#       <td>0.002</td>
#       <td>9.956</td>
#     </tr>
#     <tr>
#       <th>2.0</th>
#       <td>sex</td>
#       <td>217.000</td>
#       <td>149.000</td>
#       <td>NaN</td>
#       <td>0.214</td>
#       <td>1.542</td>
#     </tr>
#     <tr>
#       <th>1.0</th>
#       <td>sex</td>
#       <td>137.000</td>
#       <td>117.000</td>
#       <td>NaN</td>
#       <td>0.214</td>
#       <td>1.542</td>
#     </tr>
#     <tr>
#       <th>1.0</th>
#       <td>ethnic</td>
#       <td>310.000</td>
#       <td>247.000</td>
#       <td>NaN</td>
#       <td>0.064</td>
#       <td>10.435</td>
#     </tr>
#     <tr>
#       <th>3.0</th>
#       <td>ethnic</td>
#       <td>17.000</td>
#       <td>6.000</td>
#       <td>NaN</td>
#       <td>0.064</td>
#       <td>10.435</td>
#     </tr>
#     <tr>
#       <th>2.0</th>
#       <td>ethnic</td>
#       <td>14.000</td>
#       <td>3.000</td>
#       <td>NaN</td>
#       <td>0.064</td>
#       <td>10.435</td>
#     </tr>
#     <tr>
#       <th>4.0</th>
#       <td>ethnic</td>
#       <td>6.000</td>
#       <td>8.000</td>
#       <td>NaN</td>
#       <td>0.064</td>
#       <td>10.435</td>
#     </tr>
#     <tr>
#       <th>6.0</th>
#       <td>ethnic</td>
#       <td>5.000</td>
#       <td>1.000</td>
#       <td>NaN</td>
#       <td>0.064</td>
#       <td>10.435</td>
#     </tr>
#     <tr>
#       <th>5.0</th>
#       <td>ethnic</td>
#       <td>1.000</td>
#       <td>1.000</td>
#       <td>NaN</td>
#       <td>0.064</td>
#       <td>10.435</td>
#     </tr>
#     <tr>
#       <th>1.0</th>
#       <td>fin</td>
#       <td>207.000</td>
#       <td>146.000</td>
#       <td>NaN</td>
#       <td>0.637</td>
#       <td>0.901</td>
#     </tr>
#     <tr>
#       <th>2.0</th>
#       <td>fin</td>
#       <td>106.000</td>
#       <td>86.000</td>
#       <td>NaN</td>
#       <td>0.637</td>
#       <td>0.901</td>
#     </tr>
#     <tr>
#       <th>3.0</th>
#       <td>fin</td>
#       <td>40.000</td>
#       <td>34.000</td>
#       <td>NaN</td>
#       <td>0.637</td>
#       <td>0.901</td>
#     </tr>
#     <tr>
#       <th>1.0</th>
#       <td>empstat</td>
#       <td>225.000</td>
#       <td>189.000</td>
#       <td>NaN</td>
#       <td>0.068</td>
#       <td>3.340</td>
#     </tr>
#     <tr>
#       <th>2.0</th>
#       <td>empstat</td>
#       <td>128.000</td>
#       <td>77.000</td>
#       <td>NaN</td>
#       <td>0.068</td>
#       <td>3.340</td>
#     </tr>
#     <tr>
#       <th>1.0</th>
#       <td>marstat</td>
#       <td>153.000</td>
#       <td>92.000</td>
#       <td>NaN</td>
#       <td>0.005</td>
#       <td>10.516</td>
#     </tr>
#     <tr>
#       <th>2.0</th>
#       <td>marstat</td>
#       <td>141.000</td>
#       <td>141.000</td>
#       <td>NaN</td>
#       <td>0.005</td>
#       <td>10.516</td>
#     </tr>
#     <tr>
#       <th>3.0</th>
#       <td>marstat</td>
#       <td>59.000</td>
#       <td>33.000</td>
#       <td>NaN</td>
#       <td>0.005</td>
#       <td>10.516</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2></h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>variable</th>
#       <th>excluded</th>
#       <th>included</th>
#       <th>t</th>
#       <th>p</th>
#       <th>X2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0.0</th>
#       <td>gad1log</td>
#       <td>0.929</td>
#       <td>0.937</td>
#       <td>-0.353</td>
#       <td>0.724</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>0.0</th>
#       <td>phq1log</td>
#       <td>1.034</td>
#       <td>1.060</td>
#       <td>-1.265</td>
#       <td>0.206</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>0.0</th>
#       <td>age</td>
#       <td>45.747</td>
#       <td>34.480</td>
#       <td>9.352</td>
#       <td>0.000</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>0.0</th>
#       <td>cisscore</td>
#       <td>10.020</td>
#       <td>10.529</td>
#       <td>-1.196</td>
#       <td>0.232</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1.0</th>
#       <td>site</td>
#       <td>106.000</td>
#       <td>118.000</td>
#       <td>NaN</td>
#       <td>0.076</td>
#       <td>6.886</td>
#     </tr>
#     <tr>
#       <th>4.0</th>
#       <td>site</td>
#       <td>51.000</td>
#       <td>36.000</td>
#       <td>NaN</td>
#       <td>0.076</td>
#       <td>6.886</td>
#     </tr>
#     <tr>
#       <th>2.0</th>
#       <td>site</td>
#       <td>49.000</td>
#       <td>51.000</td>
#       <td>NaN</td>
#       <td>0.076</td>
#       <td>6.886</td>
#     </tr>
#     <tr>
#       <th>3.0</th>
#       <td>site</td>
#       <td>47.000</td>
#       <td>70.000</td>
#       <td>NaN</td>
#       <td>0.076</td>
#       <td>6.886</td>
#     </tr>
#     <tr>
#       <th>3.0</th>
#       <td>cis</td>
#       <td>122.000</td>
#       <td>153.000</td>
#       <td>NaN</td>
#       <td>0.185</td>
#       <td>3.377</td>
#     </tr>
#     <tr>
#       <th>2.0</th>
#       <td>cis</td>
#       <td>75.000</td>
#       <td>65.000</td>
#       <td>NaN</td>
#       <td>0.185</td>
#       <td>3.377</td>

# %% [markdown]
# Throughout both sessions patients who did not do the task properly were older, less educated, not single, and were taking antidepressants in the past.

# %%
# baseline GAD related to performance?
x = [x for x in gng_columns if 'acc' in x]
for i in x:
    panda.glm('gad1log ~ ' + i + '1 * exclusiontot1 + site + cis + dep + education + age + sex + AD_past', df_panda, [])
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                gad1log   No. Observations:                  618
# Model:                            GLM   Df Residuals:                      607
# Model Family:                Gaussian   Df Model:                           10
# Link Function:               identity   Scale:                        0.037126
# Method:                          IRLS   Log-Likelihood:                 146.32
# Date:                Sat, 18 Jun 2022   Deviance:                       22.535
# Time:                        14:17:48   Pearson chi2:                     22.5
# No. Iterations:                     3   Pseudo R-squ. (CS):             0.6108
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.4892      0.098      5.007      0.000       0.298       0.681
# acctot1                  -0.0494      0.123     -0.401      0.689      -0.291       0.192
# exclusiontot1             0.0520      0.111      0.469      0.639      -0.165       0.269
# acctot1:exclusiontot1    -0.1015      0.195     -0.520      0.603      -0.484       0.281
# site                     -0.0049      0.007     -0.736      0.461      -0.018       0.008
# cis                       0.2189      0.010     21.341      0.000       0.199       0.239
# dep                       0.0139      0.017      0.817      0.414      -0.019       0.047
# education                 0.0357      0.014      2.512      0.012       0.008       0.064
# age                      -0.0028      0.001     -4.773      0.000      -0.004      -0.002
# sex                       0.0311      0.016      1.924      0.054      -0.001       0.063
# AD_past                  -0.0139      0.017     -0.819      0.413      -0.047       0.019
# =========================================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                gad1log   No. Observations:                  618
# Model:                            GLM   Df Residuals:                      607
# Model Family:                Gaussian   Df Model:                           10
# Link Function:               identity   Scale:                        0.037073
# Method:                          IRLS   Log-Likelihood:                 146.76
# Date:                Sat, 18 Jun 2022   Deviance:                       22.503
# Time:                        14:17:48   Pearson chi2:                     22.5
# No. Iterations:                     3   Pseudo R-squ. (CS):             0.6119
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.4714      0.074      6.381      0.000       0.327       0.616
# acc_g2w1                  -0.0100      0.056     -0.179      0.858      -0.119       0.099
# exclusiontot1              0.0241      0.050      0.478      0.632      -0.075       0.123
# acc_g2w1:exclusiontot1    -0.0420      0.066     -0.637      0.524      -0.171       0.087
# site                      -0.0055      0.007     -0.825      0.410      -0.019       0.008
# cis                        0.2182      0.010     21.195      0.000       0.198       0.238
# dep                        0.0151      0.017      0.889      0.374      -0.018       0.048
# education                  0.0364      0.014      2.562      0.010       0.009       0.064
# age                       -0.0030      0.001     -4.958      0.000      -0.004      -0.002
# sex                        0.0306      0.016      1.896      0.058      -0.001       0.062
# AD_past                   -0.0127      0.017     -0.750      0.453      -0.046       0.020
# ==========================================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                gad1log   No. Observations:                  618
# Model:                            GLM   Df Residuals:                      607
# Model Family:                Gaussian   Df Model:                           10
# Link Function:               identity   Scale:                        0.037151
# Method:                          IRLS   Log-Likelihood:                 146.11
# Date:                Sat, 18 Jun 2022   Deviance:                       22.550
# Time:                        14:17:48   Pearson chi2:                     22.6
# No. Iterations:                     3   Pseudo R-squ. (CS):             0.6103
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                  0.4761      0.066      7.231      0.000       0.347       0.605
# acc_g2a1                  -0.0290      0.054     -0.536      0.592      -0.135       0.077
# exclusiontot1              0.0050      0.037      0.134      0.894      -0.068       0.078
# acc_g2a1:exclusiontot1    -0.0005      0.067     -0.008      0.994      -0.132       0.131
# site                      -0.0051      0.007     -0.759      0.448      -0.018       0.008
# cis                        0.2181      0.010     21.171      0.000       0.198       0.238
# dep                        0.0152      0.017      0.899      0.369      -0.018       0.048
# education                  0.0367      0.014      2.567      0.010       0.009       0.065
# age                       -0.0030      0.001     -4.834      0.000      -0.004      -0.002
# sex                        0.0303      0.016      1.870      0.062      -0.001       0.062
# AD_past                   -0.0124      0.017     -0.732      0.464      -0.046       0.021
# ==========================================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                gad1log   No. Observations:                  618
# Model:                            GLM   Df Residuals:                      607
# Model Family:                Gaussian   Df Model:                           10
# Link Function:               identity   Scale:                        0.037129
# Method:                          IRLS   Log-Likelihood:                 146.29
# Date:                Sat, 18 Jun 2022   Deviance:                       22.537
# Time:                        14:17:48   Pearson chi2:                     22.5
# No. Iterations:                     3   Pseudo R-squ. (CS):             0.6108
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   0.4589      0.057      8.081      0.000       0.348       0.570
# acc_ng2w1                   0.0059      0.037      0.158      0.874      -0.067       0.078
# exclusiontot1              -0.0073      0.030     -0.243      0.808      -0.067       0.052
# acc_ng2w1:exclusiontot1     0.0318      0.051      0.624      0.533      -0.068       0.132
# site                       -0.0056      0.007     -0.843      0.399      -0.019       0.007
# cis                         0.2183      0.010     21.226      0.000       0.198       0.238
# dep                         0.0156      0.017      0.920      0.358      -0.018       0.049
# education                   0.0359      0.014      2.524      0.012       0.008       0.064
# age                        -0.0030      0.001     -4.876      0.000      -0.004      -0.002
# sex                         0.0305      0.016      1.886      0.059      -0.001       0.062
# AD_past                    -0.0124      0.017     -0.731      0.465      -0.046       0.021
# ===========================================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                gad1log   No. Observations:                  618
# Model:                            GLM   Df Residuals:                      607
# Model Family:                Gaussian   Df Model:                           10
# Link Function:               identity   Scale:                        0.037186
# Method:                          IRLS   Log-Likelihood:                 145.82
# Date:                Sat, 18 Jun 2022   Deviance:                       22.572
# Time:                        14:17:48   Pearson chi2:                     22.6
# No. Iterations:                     3   Pseudo R-squ. (CS):             0.6096
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   0.4777      0.077      6.178      0.000       0.326       0.629
# acc_ng2a1                  -0.0313      0.075     -0.419      0.675      -0.178       0.115
# exclusiontot1              -0.0124      0.064     -0.194      0.846      -0.138       0.113
# acc_ng2a1:exclusiontot1     0.0280      0.086      0.325      0.745      -0.141       0.197
# site                       -0.0049      0.007     -0.730      0.465      -0.018       0.008
# cis                         0.2189      0.010     21.251      0.000       0.199       0.239
# dep                         0.0146      0.017      0.859      0.390      -0.019       0.048
# education                   0.0354      0.014      2.470      0.014       0.007       0.063
# age                        -0.0028      0.001     -4.663      0.000      -0.004      -0.002
# sex                         0.0308      0.016      1.902      0.057      -0.001       0.062
# AD_past                    -0.0126      0.017     -0.746      0.456      -0.046       0.021
# ===========================================================================================

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------
# MIXED EFFECTS MODELLING
# --------------------------------------------------------------------------------------------------------

# %%
# create dataframe for mixed-effects modelling
mle_df = pd.DataFrame(columns = gng_columns + rct_columns)
for c in gng_columns:
    if number_of_sessions == 2:
        mle_df[c] = pd.concat([df_panda[c + '1'], df_panda[c + '2']], axis=0, ignore_index=True)
    elif number_of_sessions == 3:
        mle_df[c] = pd.concat([df_panda[c + '1'], df_panda[c + '2'], df_panda[c + '3']], axis=0, ignore_index=True)
    
for c in rct_columns:
    mle_df[c] = pd.concat([df_panda[c], df_panda[c]], axis=0, ignore_index=True)


mle_df['subject'] = np.hstack((np.arange(len(df_panda)),np.arange(len(df_panda))))
mle_df['time'] = np.hstack((np.tile(1, len(df_panda)),np.tile(2, len(df_panda))))
mle_df['weeks'] = np.hstack((np.tile(weeks[0], len(df_panda)),np.tile(weeks[1], len(df_panda))))
mle_df['group'] = np.hstack((np.tile(0, len(df_panda)),df_panda['group']))
mle_df['gadlog'] = np.hstack((df_panda['gad1log'],df_panda['gad2log']))

# %%
# does exlusion criteria have an effect on the effect of sertraline on anxiety?
mle_df_group_exclusion_interaction = mle_df.copy()
for i in range(2,5):
    mle_df_group_exclusion_interaction['gadlog'] = np.hstack((df_panda['gad1log'], df_panda['gad' + str(i) + 'log']))
    model = smf.mixedlm('gadlog ~ group * exclusiontot + time + site + cis + dep', \
                        mle_df_group_exclusion_interaction, groups= 'subject', missing='drop').fit()
    print(model.summary())
# Out:
#             Mixed Linear Model Regression Results
# =============================================================
# Model:                MixedLM   Dependent Variable:   gadlog
# No. Observations:     1134      Method:               REML
# No. Groups:           624       Scale:                0.0334
# Min. group size:      1         Log-Likelihood:       59.6008
# Max. group size:      2         Converged:            Yes
# Mean group size:      1.8
# -------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept           0.488    0.042 11.498 0.000  0.405  0.571
# group              -0.017    0.025 -0.684 0.494 -0.065  0.032
# exclusiontot        0.003    0.016  0.190 0.849 -0.028  0.034
# group:exclusiontot -0.048    0.030 -1.595 0.111 -0.108  0.011
# time               -0.082    0.015 -5.573 0.000 -0.111 -0.053
# site               -0.010    0.007 -1.425 0.154 -0.023  0.004
# cis                 0.234    0.010 22.745 0.000  0.214  0.254
# dep                 0.010    0.017  0.596 0.551 -0.024  0.044
# subject Var         0.021    0.018
# =============================================================
#
#             Mixed Linear Model Regression Results
# =============================================================
# Model:              MixedLM   Dependent Variable:   gadlog
# No. Observations:   1114      Method:               REML
# No. Groups:         624       Scale:                0.0574
# Min. group size:    1         Log-Likelihood:       -144.3351
# Max. group size:    2         Converged:            Yes
# Mean group size:    1.8
# -------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept           0.564    0.049 11.422 0.000  0.467  0.661
# group              -0.084    0.031 -2.698 0.007 -0.145 -0.023
# exclusiontot        0.015    0.019  0.803 0.422 -0.022  0.052
# group:exclusiontot -0.067    0.039 -1.728 0.084 -0.142  0.009
# time               -0.172    0.019 -9.107 0.000 -0.209 -0.135
# site               -0.005    0.008 -0.652 0.514 -0.020  0.010
# cis                 0.224    0.012 19.415 0.000  0.201  0.247
# dep                 0.025    0.019  1.292 0.196 -0.013  0.063
# subject Var         0.017    0.016
# =============================================================
#
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM   Dependent Variable:   gadlog
# No. Observations:    1100      Method:               REML
# No. Groups:          624       Scale:                0.0611
# Min. group size:     1         Log-Likelihood:       -158.1900
# Max. group size:     2         Converged:            Yes
# Mean group size:     1.8
# --------------------------------------------------------------
#                    Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept           0.604    0.050  11.983 0.000  0.505  0.703
# group              -0.102    0.032  -3.173 0.002 -0.165 -0.039
# exclusiontot        0.003    0.019   0.174 0.862 -0.034  0.041
# group:exclusiontot -0.046    0.039  -1.160 0.246 -0.123  0.032
# time               -0.225    0.020 -11.337 0.000 -0.264 -0.186
# site               -0.002    0.008  -0.217 0.828 -0.017  0.014
# cis                 0.217    0.012  18.777 0.000  0.195  0.240
# dep                 0.046    0.020   2.351 0.019  0.008  0.084
# subject Var         0.015    0.016
# ==============================================================

# %% [markdown]
# The effect of sertraline on anxiety is significanly higher in the excluded group at week 6! The exclusion criteria itself has no effect on anxiety!

# %%
# Post-hoc influence of group on anxiety in excluded and included
mle_df_group_exclusion_interaction['gadlog'] = np.hstack((df_panda['gad1log'], df_panda['gad3log']))
for i in range(2):
    model = smf.mixedlm('gadlog ~ group + time + site + cis + dep + age + education + AD_past + marstat', \
                        mle_df_group_exclusion_interaction[mle_df_group_exclusion_interaction['exclusiontot']==i], groups= 'subject', missing='drop').fit()
    print(model.summary())
# Out:
#         Mixed Linear Model Regression Results
# ======================================================
# Model:            MixedLM Dependent Variable: gadlog
# No. Observations: 527     Method:             REML
# No. Groups:       368     Scale:              0.0592
# Min. group size:  1       Log-Likelihood:     -86.6396
# Max. group size:  2       Converged:          Yes
# Mean group size:  1.4
# ------------------------------------------------------
#             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------
# Intercept    0.609    0.100  6.088 0.000  0.413  0.805
# group       -0.072    0.034 -2.145 0.032 -0.139 -0.006
# time        -0.193    0.026 -7.285 0.000 -0.245 -0.141
# site         0.000    0.011  0.008 0.993 -0.022  0.022
# cis          0.191    0.017 11.449 0.000  0.158  0.224
# dep          0.030    0.028  1.075 0.282 -0.024  0.084
# age         -0.004    0.001 -3.359 0.001 -0.006 -0.001
# education    0.013    0.029  0.465 0.642 -0.043  0.070
# AD_past      0.036    0.026  1.400 0.161 -0.015  0.087
# marstat      0.054    0.020  2.743 0.006  0.015  0.092
# subject Var  0.015    0.034
# ======================================================
#
#         Mixed Linear Model Regression Results
# ======================================================
# Model:            MixedLM Dependent Variable: gadlog
# No. Observations: 587     Method:             REML
# No. Groups:       415     Scale:              0.0598
# Min. group size:  1       Log-Likelihood:     -82.5770
# Max. group size:  2       Converged:          Yes
# Mean group size:  1.4
# ------------------------------------------------------
#             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------
# Intercept    0.591    0.088  6.750 0.000  0.419  0.763
# group       -0.177    0.035 -5.079 0.000 -0.245 -0.109
# time        -0.131    0.029 -4.549 0.000 -0.188 -0.075
# site        -0.001    0.010 -0.084 0.933 -0.020  0.019
# cis          0.236    0.015 15.604 0.000  0.206  0.265
# dep          0.034    0.025  1.358 0.175 -0.015  0.082
# age         -0.003    0.001 -4.002 0.000 -0.005 -0.002
# education    0.021    0.019  1.128 0.259 -0.016  0.058
# AD_past      0.002    0.026  0.092 0.927 -0.048  0.053
# marstat     -0.000    0.016 -0.023 0.982 -0.031  0.030
# subject Var  0.011    0.023
# ======================================================

# %%
# does the group have an effect on accuracy when controlling for the exclusion group?
x = [x for x in gng_columns if 'acc' in x]
for i in x:
    model = smf.mixedlm(i+' ~ group*exclusiontot + site + cis + dep + time', \
                    mle_df, groups= 'subject', missing='drop').fit()
    print(model.summary())
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM   Dependent Variable:   acctot
# No. Observations:    1146      Method:               REML
# No. Groups:          625       Scale:                0.0063
# Min. group size:     1         Log-Likelihood:       1154.9495
# Max. group size:     2         Converged:            Yes
# Mean group size:     1.8
# --------------------------------------------------------------
#                    Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept           0.643    0.015  42.090 0.000  0.613  0.673
# group               0.027    0.010   2.813 0.005  0.008  0.047
# exclusiontot       -0.151    0.006 -25.429 0.000 -0.163 -0.139
# group:exclusiontot -0.039    0.012  -3.273 0.001 -0.063 -0.016
# site                0.003    0.002   1.210 0.226 -0.002  0.007
# cis                -0.003    0.003  -0.957 0.339 -0.010  0.004
# dep                 0.001    0.006   0.131 0.896 -0.011  0.012
# time                0.006    0.006   1.033 0.302 -0.006  0.018
# subject Var         0.001    0.005
# ==============================================================
#
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:                MixedLM   Dependent Variable:   acc_g2w
# No. Observations:     1146      Method:               REML
# No. Groups:           625       Scale:                0.0389
# Min. group size:      1         Log-Likelihood:       -36.5167
# Max. group size:      2         Converged:            Yes
# Mean group size:      1.8
# --------------------------------------------------------------
#                    Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept           0.875    0.046  19.034 0.000  0.785  0.966
# group               0.055    0.027   2.088 0.037  0.003  0.108
# exclusiontot       -0.395    0.017 -23.226 0.000 -0.428 -0.362
# group:exclusiontot -0.021    0.033  -0.648 0.517 -0.085  0.043
# site               -0.013    0.008  -1.789 0.074 -0.028  0.001
# cis                -0.011    0.011  -1.002 0.316 -0.033  0.011
# dep                -0.001    0.019  -0.069 0.945 -0.039  0.036
# time               -0.000    0.016  -0.001 0.999 -0.031  0.031
# subject Var         0.026    0.021
# ==============================================================
#
#             Mixed Linear Model Regression Results
# =============================================================
# Model:                MixedLM   Dependent Variable:   acc_g2a
# No. Observations:     1146      Method:               REML
# No. Groups:           625       Scale:                0.0309
# Min. group size:      1         Log-Likelihood:       30.9003
# Max. group size:      2         Converged:            Yes
# Mean group size:      1.8
# -------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept           0.579    0.045 12.974 0.000  0.491  0.666
# group               0.064    0.024  2.615 0.009  0.016  0.111
# exclusiontot       -0.130    0.016 -8.018 0.000 -0.162 -0.098
# group:exclusiontot -0.055    0.030 -1.865 0.062 -0.114  0.003
# site               -0.008    0.007 -1.042 0.297 -0.022  0.007
# cis                -0.020    0.011 -1.811 0.070 -0.042  0.002
# dep                -0.005    0.019 -0.245 0.807 -0.041  0.032
# time                0.026    0.014  1.827 0.068 -0.002  0.054
# subject Var         0.029    0.023
# =============================================================
#
#             Mixed Linear Model Regression Results
# =============================================================
# Model:              MixedLM   Dependent Variable:   acc_ng2w
# No. Observations:   1146      Method:               REML
# No. Groups:         625       Scale:                0.0742
# Min. group size:    1         Log-Likelihood:       -306.7372
# Max. group size:    2         Converged:            Yes
# Mean group size:    1.8
# -------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept           0.373    0.056  6.621 0.000  0.263  0.484
# group              -0.008    0.035 -0.225 0.822 -0.076  0.060
# exclusiontot        0.050    0.022  2.305 0.021  0.007  0.093
# group:exclusiontot -0.051    0.043 -1.184 0.236 -0.134  0.033
# site                0.027    0.009  3.070 0.002  0.010  0.045
# cis                 0.013    0.013  0.980 0.327 -0.013  0.039
# dep                 0.017    0.022  0.741 0.459 -0.027  0.060
# time               -0.003    0.021 -0.124 0.901 -0.044  0.039
# subject Var         0.025    0.020
# =============================================================
#
#             Mixed Linear Model Regression Results
# =============================================================
# Model:               MixedLM   Dependent Variable:   acc_ng2a
# No. Observations:    1146      Method:               REML
# No. Groups:          625       Scale:                0.0250
# Min. group size:     1         Log-Likelihood:       195.6418
# Max. group size:     2         Converged:            Yes
# Mean group size:     1.8
# -------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept           0.709    0.038 18.751 0.000  0.635  0.783
# group              -0.008    0.021 -0.386 0.700 -0.050  0.034
# exclusiontot       -0.094    0.014 -6.865 0.000 -0.121 -0.067
# group:exclusiontot -0.022    0.026 -0.851 0.395 -0.074  0.029
# site                0.006    0.006  0.918 0.359 -0.006  0.018
# cis                 0.007    0.009  0.791 0.429 -0.011  0.026
# dep                -0.005    0.016 -0.315 0.753 -0.036  0.026
# time                0.007    0.013  0.556 0.578 -0.018  0.032
# subject Var         0.019    0.018
# =============================================================

# %% [markdown]
# Within the group of patients who did the task properly, sertraline increased overall accuracy driven by the g2a condition and the influence of sertraline on task performance was significantly smaller in the patient group who did not do the task properly.

# %%
# Post-hoc influence of group on accuracy
for j in range(2):
    model = smf.mixedlm('acctot ~ group + site + cis + dep + time + age + education + AD_past + marstat', \
                mle_df[mle_df['exclusiontot']==j], groups= 'subject', missing='drop').fit()
    print(model.summary())
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#         Mixed Linear Model Regression Results
# ======================================================
# Model:            MixedLM Dependent Variable: acctot
# No. Observations: 540     Method:             REML
# No. Groups:       372     Scale:              0.0088
# Min. group size:  1       Log-Likelihood:     441.9116
# Max. group size:  2       Converged:          Yes
# Mean group size:  1.5
# ------------------------------------------------------
#             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------
# Intercept    0.725    0.036 20.162 0.000  0.654  0.795
# group        0.023    0.012  1.921 0.055 -0.000  0.047
# site         0.008    0.004  1.971 0.049  0.000  0.016
# cis         -0.014    0.006 -2.305 0.021 -0.025 -0.002
# dep          0.017    0.010  1.777 0.076 -0.002  0.037
# time         0.013    0.010  1.309 0.191 -0.006  0.032
# age         -0.002    0.000 -4.584 0.000 -0.002 -0.001
# education   -0.012    0.010 -1.135 0.256 -0.032  0.008
# AD_past     -0.010    0.009 -1.139 0.255 -0.029  0.008
# marstat     -0.005    0.007 -0.746 0.456 -0.019  0.008
# subject Var  0.001    0.009
# ======================================================
#
#         Mixed Linear Model Regression Results
# ======================================================
# Model:            MixedLM Dependent Variable: acctot
# No. Observations: 606     Method:             REML
# No. Groups:       419     Scale:              0.0038
# Min. group size:  1       Log-Likelihood:     723.3475
# Max. group size:  2       Converged:          Yes
# Mean group size:  1.4
# ------------------------------------------------------
#             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------
# Intercept    0.530    0.022 23.771 0.000  0.486  0.574
# group       -0.008    0.009 -0.900 0.368 -0.025  0.009
# site        -0.001    0.003 -0.547 0.584 -0.006  0.004
# cis         -0.003    0.004 -0.655 0.512 -0.010  0.005
# dep         -0.010    0.006 -1.626 0.104 -0.023  0.002
# time         0.002    0.007  0.332 0.740 -0.012  0.017
# age          0.000    0.000  0.400 0.689 -0.000  0.001
# education    0.004    0.005  0.776 0.438 -0.006  0.013
# AD_past     -0.015    0.007 -2.244 0.025 -0.028 -0.002
# marstat      0.002    0.004  0.492 0.623 -0.006  0.010
# subject Var  0.001    0.007
# ======================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %%
# does task performance have an effect on gad at 6 weeks controlled for the exclusion and drug group?
mle_df['gadlog'] = np.hstack((df_panda['gad1log'], df_panda['gad3log']))
x = [x for x in gng_columns if 'acc' in x]
for i in x:
    model = smf.mixedlm('gadlog ~ '+i+' * exclusiontot * group + time + age + education + sex', \
                    mle_df, groups= 'subject', re_formula='~'+i+'', missing='drop').fit()
    print(model.summary())
# Out:
#                Mixed Linear Model Regression Results
# ====================================================================
# Model:                 MixedLM     Dependent Variable:     gadlog
# No. Observations:      1114        Method:                 REML
# No. Groups:            624         Scale:                  0.0566
# Min. group size:       1           Log-Likelihood:         -272.9454
# Max. group size:       2           Converged:              Yes
# Mean group size:       1.8
# --------------------------------------------------------------------
#                           Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------------
# Intercept                  1.337    0.115 11.667 0.000  1.113  1.562
# acctot                    -0.118    0.148 -0.797 0.426 -0.409  0.173
# exclusiontot              -0.051    0.140 -0.364 0.716 -0.326  0.224
# acctot:exclusiontot        0.155    0.251  0.618 0.537 -0.337  0.647
# group                     -0.397    0.190 -2.095 0.036 -0.768 -0.025
# acctot:group               0.452    0.276  1.635 0.102 -0.090  0.993
# exclusiontot:group         0.506    0.287  1.763 0.078 -0.057  1.069
# acctot:exclusiontot:group -0.977    0.513 -1.904 0.057 -1.983  0.029
# time                      -0.167    0.020 -8.458 0.000 -0.206 -0.128
# age                       -0.006    0.001 -7.149 0.000 -0.007 -0.004
# education                  0.020    0.020  0.971 0.331 -0.020  0.059
# sex                        0.015    0.023  0.673 0.501 -0.029  0.059
# subject Var                0.107    0.281
# subject x acctot Cov      -0.102    0.439
# acctot Var                 0.155    0.705
# ====================================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# =====================================================================
# Model:                  MixedLM     Dependent Variable:     gadlog
# No. Observations:       1114        Method:                 REML
# No. Groups:             624         Scale:                  0.0567
# Min. group size:        1           Log-Likelihood:         -259.0893
# Max. group size:        2           Converged:              Yes
# Mean group size:        1.8
# ---------------------------------------------------------------------
#                            Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------
# Intercept                   1.381    0.082 16.759 0.000  1.219  1.542
# acc_g2w                    -0.125    0.070 -1.800 0.072 -0.262  0.011
# exclusiontot               -0.018    0.063 -0.277 0.782 -0.142  0.107
# acc_g2w:exclusiontot        0.037    0.084  0.436 0.663 -0.128  0.201
# group                      -0.569    0.166 -3.427 0.001 -0.894 -0.243
# acc_g2w:group               0.548    0.185  2.966 0.003  0.186  0.911
# exclusiontot:group          0.592    0.173  3.422 0.001  0.253  0.931
# acc_g2w:exclusiontot:group -0.914    0.207 -4.421 0.000 -1.320 -0.509
# time                       -0.167    0.020 -8.529 0.000 -0.205 -0.129
# age                        -0.006    0.001 -7.824 0.000 -0.008 -0.005
# education                   0.025    0.020  1.249 0.212 -0.014  0.063
# sex                         0.011    0.022  0.481 0.631 -0.033  0.054
# subject Var                 0.031    0.046
# subject x acc_g2w Cov       0.006    0.061
# acc_g2w Var                 0.001    0.108
# =====================================================================
#
#                 Mixed Linear Model Regression Results
# =====================================================================
# Model:                  MixedLM     Dependent Variable:     gadlog
# No. Observations:       1114        Method:                 REML
# No. Groups:             624         Scale:                  0.0562
# Min. group size:        1           Log-Likelihood:         -274.0556
# Max. group size:        2           Converged:              Yes
# Mean group size:        1.8
# ---------------------------------------------------------------------
#                            Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------
# Intercept                   1.306    0.074 17.722 0.000  1.162  1.451
# acc_g2a                    -0.061    0.068 -0.904 0.366 -0.194  0.071
# exclusiontot                0.040    0.047  0.856 0.392 -0.052  0.131
# acc_g2a:exclusiontot       -0.005    0.086 -0.057 0.954 -0.173  0.164
# group                      -0.103    0.097 -1.055 0.291 -0.293  0.088
# acc_g2a:group               0.028    0.144  0.193 0.847 -0.255  0.310
# exclusiontot:group          0.044    0.110  0.402 0.688 -0.171  0.260
# acc_g2a:exclusiontot:group -0.241    0.180 -1.344 0.179 -0.594  0.111
# time                       -0.166    0.020 -8.401 0.000 -0.205 -0.127
# age                        -0.006    0.001 -7.507 0.000 -0.008 -0.004
# education                   0.022    0.020  1.108 0.268 -0.017  0.062
# sex                         0.014    0.023  0.616 0.538 -0.030  0.058
# subject Var                 0.048    0.054
# subject x acc_g2a Cov      -0.023    0.096
# acc_g2a Var                 0.058    0.207
# =====================================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM      Dependent Variable:      gadlog
# No. Observations:      1114         Method:                  REML
# No. Groups:            624          Scale:                   0.0580
# Min. group size:       1            Log-Likelihood:          -274.0667
# Max. group size:       2            Converged:               Yes
# Mean group size:       1.8
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    1.271    0.063 20.056 0.000  1.147  1.395
# acc_ng2w                     0.024    0.044  0.540 0.590 -0.063  0.111
# exclusiontot                 0.018    0.038  0.458 0.647 -0.058  0.093
# acc_ng2w:exclusiontot        0.063    0.064  0.987 0.324 -0.062  0.188
# group                       -0.126    0.052 -2.407 0.016 -0.229 -0.023
# acc_ng2w:group               0.082    0.088  0.933 0.351 -0.090  0.254
# exclusiontot:group          -0.097    0.074 -1.309 0.191 -0.242  0.048
# acc_ng2w:exclusiontot:group  0.083    0.126  0.655 0.512 -0.165  0.331
# time                        -0.167    0.020 -8.457 0.000 -0.206 -0.128
# age                         -0.006    0.001 -7.718 0.000 -0.008 -0.005
# education                    0.020    0.020  0.992 0.321 -0.019  0.059
# sex                          0.011    0.022  0.507 0.612 -0.033  0.055
# subject Var                  0.044    0.056
# subject x acc_ng2w Cov      -0.004    0.075
# acc_ng2w Var                 0.001    0.133
# ======================================================================
#
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:                 MixedLM      Dependent Variable:      gadlog
# No. Observations:      1114         Method:                  REML
# No. Groups:            624          Scale:                   0.0560
# Min. group size:       1            Log-Likelihood:          -267.8812
# Max. group size:       2            Converged:               Yes
# Mean group size:       1.8
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    1.282    0.092 13.945 0.000  1.102  1.463
# acc_ng2a                    -0.022    0.096 -0.233 0.816 -0.210  0.165
# exclusiontot                -0.012    0.082 -0.147 0.883 -0.174  0.149
# acc_ng2a:exclusiontot        0.087    0.111  0.786 0.432 -0.130  0.305
# group                       -0.021    0.143 -0.146 0.884 -0.301  0.259
# acc_ng2a:group              -0.090    0.187 -0.484 0.629 -0.457  0.276
# exclusiontot:group          -0.374    0.161 -2.317 0.021 -0.690 -0.058
# acc_ng2a:exclusiontot:group  0.498    0.220  2.262 0.024  0.066  0.929
# time                        -0.169    0.020 -8.587 0.000 -0.207 -0.130
# age                         -0.006    0.001 -7.599 0.000 -0.007 -0.004
# education                    0.026    0.020  1.263 0.207 -0.014  0.065
# sex                          0.015    0.023  0.681 0.496 -0.029  0.059
# subject Var                  0.068    0.136
# subject x acc_ng2a Cov      -0.043    0.191
# acc_ng2a Var                 0.063    0.288
# ======================================================================

# %%
# do cognitive parameters differ between drug group controlling for exclusion group?
for i in parameter_labels:
    model = smf.mixedlm(i + ' ~ group * exclusiontot + time + site + cis + dep', \
                        mle_df, groups= 'subject', missing='drop').fit()
    print(model.summary())
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#             Mixed Linear Model Regression Results
# =============================================================
# Model:               MixedLM  Dependent Variable:  rew_se
# No. Observations:    1146     Method:              REML
# No. Groups:          625      Scale:               1.2653
# Min. group size:     1        Log-Likelihood:      -1771.8913
# Max. group size:     2        Converged:           Yes
# Mean group size:     1.8
# -------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept           3.278    0.195 16.791 0.000  2.896  3.661
# group               0.270    0.129  2.100 0.036  0.018  0.523
# exclusiontot       -0.604    0.077 -7.855 0.000 -0.755 -0.453
# group:exclusiontot -0.263    0.160 -1.648 0.099 -0.576  0.050
# time               -0.061    0.083 -0.734 0.463 -0.225  0.102
# site               -0.035    0.029 -1.206 0.228 -0.091  0.022
# cis                -0.030    0.043 -0.698 0.485 -0.113  0.054
# dep                -0.092    0.072 -1.278 0.201 -0.234  0.049
# subject Var         0.000    0.050
# =============================================================
#
#             Mixed Linear Model Regression Results
# =============================================================
# Model:               MixedLM  Dependent Variable:  loss_se
# No. Observations:    1146     Method:              REML
# No. Groups:          625      Scale:               0.7631
# Min. group size:     1        Log-Likelihood:      -1648.6935
# Max. group size:     2        Converged:           Yes
# Mean group size:     1.8
# -------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept           1.017    0.184  5.522 0.000  0.656  1.377
# group              -0.032    0.113 -0.285 0.776 -0.253  0.189
# exclusiontot       -0.606    0.070 -8.660 0.000 -0.744 -0.469
# group:exclusiontot -0.146    0.138 -1.054 0.292 -0.417  0.125
# time                0.164    0.068  2.397 0.017  0.030  0.298
# site                0.040    0.029  1.378 0.168 -0.017  0.097
# cis                 0.021    0.044  0.476 0.634 -0.065  0.106
# dep                -0.023    0.074 -0.310 0.756 -0.167  0.121
# subject Var         0.295    0.069
# =============================================================
#
#             Mixed Linear Model Regression Results
# =============================================================
# Model:               MixedLM  Dependent Variable:  rew_LR
# No. Observations:    1146     Method:              REML
# No. Groups:          625      Scale:               1.4795
# Min. group size:     1        Log-Likelihood:      -1897.8672
# Max. group size:     2        Converged:           Yes
# Mean group size:     1.8
# -------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept          -2.065    0.220 -9.375 0.000 -2.497 -1.633
# group               0.054    0.144  0.374 0.708 -0.228  0.335
# exclusiontot       -0.534    0.086 -6.184 0.000 -0.703 -0.365
# group:exclusiontot -0.216    0.178 -1.216 0.224 -0.565  0.132
# time                0.138    0.091  1.505 0.132 -0.042  0.317
# site               -0.023    0.033 -0.681 0.496 -0.087  0.042
# cis                -0.036    0.049 -0.726 0.468 -0.132  0.061
# dep                -0.052    0.083 -0.630 0.529 -0.215  0.110
# subject Var         0.103    0.063
# =============================================================
#
#             Mixed Linear Model Regression Results
# =============================================================
# Model:               MixedLM  Dependent Variable:  loss_LR
# No. Observations:    1146     Method:              REML
# No. Groups:          625      Scale:               2.2810
# Min. group size:     1        Log-Likelihood:      -2215.6055
# Max. group size:     2        Converged:           Yes
# Mean group size:     1.8
# -------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept          -0.441    0.298 -1.481 0.138 -1.024  0.142
# group               0.470    0.188  2.506 0.012  0.103  0.838
# exclusiontot        0.069    0.115  0.602 0.547 -0.156  0.294
# group:exclusiontot -0.291    0.231 -1.260 0.208 -0.745  0.162
# time               -0.179    0.116 -1.543 0.123 -0.407  0.048
# site               -0.064    0.046 -1.396 0.163 -0.155  0.026
# cis                -0.058    0.069 -0.851 0.395 -0.193  0.076
# dep                -0.052    0.116 -0.450 0.653 -0.280  0.175
# subject Var         0.525    0.098
# =============================================================
#
#             Mixed Linear Model Regression Results
# =============================================================
# Model:              MixedLM   Dependent Variable:   app_Pav
# No. Observations:   1146      Method:               REML
# No. Groups:         625       Scale:                0.2425
# Min. group size:    1         Log-Likelihood:       -875.5637
# Max. group size:    2         Converged:            Yes
# Mean group size:    1.8
# -------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept          -0.035    0.090 -0.387 0.699 -0.211  0.141
# group               0.097    0.058  1.656 0.098 -0.018  0.211
# exclusiontot        0.011    0.035  0.320 0.749 -0.058  0.081
# group:exclusiontot -0.048    0.072 -0.667 0.505 -0.190  0.093
# time               -0.100    0.037 -2.695 0.007 -0.173 -0.027
# site               -0.035    0.014 -2.596 0.009 -0.062 -0.009
# cis                -0.005    0.020 -0.264 0.792 -0.045  0.034
# dep                -0.040    0.034 -1.189 0.234 -0.107  0.026
# subject Var         0.020    0.025
# =============================================================
#
#             Mixed Linear Model Regression Results
# =============================================================
# Model:               MixedLM  Dependent Variable:  av_Pav
# No. Observations:    1146     Method:              REML
# No. Groups:          625      Scale:               0.3119
# Min. group size:     1        Log-Likelihood:      -1184.8352
# Max. group size:     2        Converged:           Yes
# Mean group size:     1.8
# -------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept          -0.637    0.125 -5.111 0.000 -0.881 -0.393
# group              -0.133    0.074 -1.803 0.071 -0.278  0.012
# exclusiontot        0.197    0.047  4.219 0.000  0.106  0.289
# group:exclusiontot  0.089    0.090  0.982 0.326 -0.088  0.266
# time                0.007    0.044  0.159 0.873 -0.080  0.094
# site                0.014    0.020  0.701 0.483 -0.025  0.053
# cis                 0.019    0.030  0.631 0.528 -0.040  0.078
# dep                -0.008    0.051 -0.162 0.871 -0.108  0.091
# subject Var         0.167    0.050
# =============================================================
#
#             Mixed Linear Model Regression Results
# =============================================================
# Model:               MixedLM  Dependent Variable:  noise
# No. Observations:    1146     Method:              REML
# No. Groups:          625      Scale:               1.7995
# Min. group size:     1        Log-Likelihood:      -2067.4633
# Max. group size:     2        Converged:           Yes
# Mean group size:     1.8
# -------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept           1.947    0.260  7.488 0.000  1.437  2.457
# group              -0.152    0.165 -0.919 0.358 -0.476  0.172
# exclusiontot        0.116    0.101  1.156 0.248 -0.081  0.314
# group:exclusiontot  0.044    0.204  0.217 0.828 -0.355  0.443
# time                0.165    0.103  1.601 0.109 -0.037  0.366
# site                0.109    0.040  2.726 0.006  0.031  0.188
# cis                 0.096    0.060  1.607 0.108 -0.021  0.213
# dep                 0.138    0.101  1.371 0.170 -0.059  0.336
# subject Var         0.355    0.084
# =============================================================
#             Mixed Linear Model Regression Results
# =============================================================
# Model:               MixedLM  Dependent Variable:  bias
# No. Observations:    1146     Method:              REML
# No. Groups:          625      Scale:               0.8218
# Min. group size:     1        Log-Likelihood:      -1801.6196
# Max. group size:     2        Converged:           Yes
# Mean group size:     1.8
# -------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept           0.177    0.220  0.804 0.421 -0.254  0.607
# group               0.170    0.124  1.371 0.170 -0.073  0.412
# exclusiontot       -0.442    0.081 -5.441 0.000 -0.602 -0.283
# group:exclusiontot -0.142    0.151 -0.938 0.348 -0.439  0.155
# time                0.158    0.073  2.159 0.031  0.015  0.302
# site               -0.060    0.036 -1.647 0.100 -0.131  0.011
# cis                -0.068    0.054 -1.259 0.208 -0.175  0.038
# dep                -0.015    0.092 -0.166 0.868 -0.195  0.164
# subject Var         0.651    0.108
# =============================================================
#
#             Mixed Linear Model Regression Results
# =============================================================
# Model:               MixedLM  Dependent Variable:  rbias
# No. Observations:    1146     Method:              REML
# No. Groups:          625      Scale:               0.5338
# Min. group size:     1        Log-Likelihood:      -1589.7889
# Max. group size:     2        Converged:           Yes
# Mean group size:     1.8
# -------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept           0.398    0.185  2.150 0.032  0.035  0.760
# group               0.155    0.101  1.533 0.125 -0.043  0.354
# exclusiontot       -0.573    0.067 -8.584 0.000 -0.704 -0.442
# group:exclusiontot  0.012    0.124  0.094 0.925 -0.231  0.254
# time               -0.000    0.060 -0.003 0.998 -0.117  0.116
# site               -0.070    0.031 -2.279 0.023 -0.131 -0.010
# cis                -0.069    0.046 -1.493 0.135 -0.160  0.022
# dep                -0.002    0.078 -0.023 0.982 -0.155  0.151
# subject Var         0.506    0.098
# =============================================================

# %%
# do cognitive parameters have an effect on gad at 6 weeks controlled for the exclusion and drug group?
mle_df['gadlog'] = np.hstack((df_panda['gad1log'], df_panda['gad3log']))
for i in parameter_labels:
    model = smf.mixedlm('gadlog ~ ' + i + '*exclusiontot * group + time + age + education + sex', \
                        mle_df, groups= 'subject', re_formula='~' + i, missing='drop').fit()
    print(model.summary())
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 394.741571
#   warnings.warn(msg, ConvergenceWarning)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
#                Mixed Linear Model Regression Results
# ====================================================================
# Model:                 MixedLM     Dependent Variable:     gadlog
# No. Observations:      1114        Method:                 REML
# No. Groups:            624         Scale:                  0.0385
# Min. group size:       1           Log-Likelihood:         -438.7385
# Max. group size:       2           Converged:              No
# Mean group size:       1.8
# --------------------------------------------------------------------
#                           Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------------
# Intercept                  1.326    0.079 16.865 0.000  1.172  1.480
# rew_se                    -0.007    0.016 -0.451 0.652 -0.039  0.025
# exclusiontot               0.042    0.051  0.826 0.409 -0.058  0.142
# rew_se:exclusiontot        0.000    0.019  0.004 0.997 -0.037  0.037
# group                     -0.193    0.103 -1.879 0.060 -0.394  0.008
# rew_se:group               0.041    0.033  1.217 0.224 -0.025  0.106
# exclusiontot:group         0.011    0.117  0.094 0.925 -0.218  0.240
# rew_se:exclusiontot:group -0.019    0.041 -0.452 0.651 -0.100  0.062
# time                      -0.172    0.019 -9.276 0.000 -0.209 -0.136
# age                       -0.006    0.001 -6.618 0.000 -0.008 -0.004
# education                  0.014    0.022  0.611 0.541 -0.030  0.057
# sex                        0.003    0.026  0.108 0.914 -0.049  0.055
# subject Var                0.046    0.045
# subject x rew_se Cov      -0.022    0.020
# rew_se Var                 0.027
# ====================================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# =====================================================================
# Model:                  MixedLM     Dependent Variable:     gadlog
# No. Observations:       1114        Method:                 REML
# No. Groups:             624         Scale:                  0.0567
# Min. group size:        1           Log-Likelihood:         -272.0403
# Max. group size:        2           Converged:              Yes
# Mean group size:        1.8
# ---------------------------------------------------------------------
#                            Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------
# Intercept                   1.273    0.063 20.102 0.000  1.149  1.397
# loss_se                    -0.004    0.016 -0.245 0.806 -0.035  0.028
# exclusiontot                0.042    0.031  1.346 0.178 -0.019  0.103
# loss_se:exclusiontot        0.004    0.020  0.204 0.838 -0.035  0.044
# group                      -0.075    0.059 -1.277 0.202 -0.191  0.040
# loss_se:group              -0.009    0.034 -0.275 0.784 -0.075  0.057
# exclusiontot:group         -0.150    0.065 -2.310 0.021 -0.278 -0.023
# loss_se:exclusiontot:group  0.129    0.042  3.037 0.002  0.046  0.212
# time                       -0.167    0.020 -8.506 0.000 -0.206 -0.129
# age                        -0.006    0.001 -7.526 0.000 -0.007 -0.004
# education                   0.021    0.020  1.045 0.296 -0.018  0.060
# sex                         0.014    0.022  0.624 0.533 -0.030  0.058
# subject Var                 0.042    0.031
# subject x loss_se Cov      -0.000    0.012
# loss_se Var                 0.000    0.011
# =====================================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 350.515622
#   warnings.warn(msg, ConvergenceWarning)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
#                Mixed Linear Model Regression Results
# ====================================================================
# Model:                 MixedLM     Dependent Variable:     gadlog
# No. Observations:      1114        Method:                 REML
# No. Groups:            624         Scale:                  0.0397
# Min. group size:       1           Log-Likelihood:         -388.1001
# Max. group size:       2           Converged:              No
# Mean group size:       1.8
# --------------------------------------------------------------------
#                           Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------------
# Intercept                  1.234    0.068 18.275 0.000  1.101  1.366
# rew_LR                    -0.035    0.014 -2.394 0.017 -0.063 -0.006
# exclusiontot               0.119    0.043  2.746 0.006  0.034  0.205
# rew_LR:exclusiontot        0.038    0.018  2.124 0.034  0.003  0.072
# group                      0.021    0.064  0.327 0.744 -0.104  0.145
# rew_LR:group               0.053    0.029  1.859 0.063 -0.003  0.110
# exclusiontot:group        -0.347    0.091 -3.832 0.000 -0.524 -0.169
# rew_LR:exclusiontot:group -0.120    0.037 -3.218 0.001 -0.192 -0.047
# time                      -0.169    0.019 -8.930 0.000 -0.206 -0.132
# age                       -0.006    0.001 -6.970 0.000 -0.008 -0.004
# education                 -0.003    0.022 -0.130 0.897 -0.046  0.040
# sex                        0.015    0.024  0.617 0.537 -0.033  0.062
# subject Var                0.047    0.039
# subject x rew_LR Cov       0.022    0.011
# rew_LR Var                 0.024
# ====================================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# =====================================================================
# Model:                  MixedLM     Dependent Variable:     gadlog
# No. Observations:       1114        Method:                 REML
# No. Groups:             624         Scale:                  0.0564
# Min. group size:        1           Log-Likelihood:         -273.2079
# Max. group size:        2           Converged:              Yes
# Mean group size:        1.8
# ---------------------------------------------------------------------
#                            Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------
# Intercept                   1.276    0.060 21.144 0.000  1.158  1.394
# loss_LR                     0.007    0.010  0.683 0.494 -0.012  0.026
# exclusiontot                0.036    0.025  1.461 0.144 -0.012  0.085
# loss_LR:exclusiontot       -0.012    0.012 -0.968 0.333 -0.036  0.012
# group                      -0.101    0.037 -2.698 0.007 -0.174 -0.028
# loss_LR:group              -0.014    0.021 -0.643 0.520 -0.055  0.028
# exclusiontot:group         -0.110    0.046 -2.375 0.018 -0.200 -0.019
# loss_LR:exclusiontot:group -0.053    0.026 -2.027 0.043 -0.104 -0.002
# time                       -0.166    0.020 -8.491 0.000 -0.205 -0.128
# age                        -0.006    0.001 -7.520 0.000 -0.007 -0.004
# education                   0.018    0.020  0.916 0.359 -0.021  0.058
# sex                         0.014    0.022  0.641 0.521 -0.029  0.058
# subject Var                 0.043    0.029
# subject x loss_LR Cov       0.001    0.007
# loss_LR Var                 0.000    0.004
# =====================================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                 Mixed Linear Model Regression Results
# =====================================================================
# Model:                  MixedLM     Dependent Variable:     gadlog
# No. Observations:       1114        Method:                 REML
# No. Groups:             624         Scale:                  0.0577
# Min. group size:        1           Log-Likelihood:         -281.9318
# Max. group size:        2           Converged:              Yes
# Mean group size:        1.8
# ---------------------------------------------------------------------
#                            Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------
# Intercept                   1.269    0.061 20.632 0.000  1.148  1.389
# app_Pav                    -0.003    0.029 -0.110 0.912 -0.059  0.053
# exclusiontot                0.042    0.025  1.695 0.090 -0.007  0.090
# app_Pav:exclusiontot       -0.014    0.040 -0.361 0.718 -0.093  0.064
# group                      -0.099    0.038 -2.608 0.009 -0.174 -0.025
# app_Pav:group              -0.040    0.057 -0.703 0.482 -0.151  0.071
# exclusiontot:group         -0.058    0.048 -1.200 0.230 -0.153  0.037
# app_Pav:exclusiontot:group  0.010    0.080  0.121 0.904 -0.148  0.167
# time                       -0.170    0.020 -8.541 0.000 -0.209 -0.131
# age                        -0.006    0.001 -7.160 0.000 -0.007 -0.004
# education                   0.017    0.020  0.865 0.387 -0.022  0.057
# sex                         0.013    0.023  0.576 0.564 -0.031  0.057
# subject Var                 0.043    0.029
# subject x app_Pav Cov       0.003    0.020
# app_Pav Var                 0.003    0.037
# =====================================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                Mixed Linear Model Regression Results
# ====================================================================
# Model:                 MixedLM     Dependent Variable:     gadlog
# No. Observations:      1114        Method:                 REML
# No. Groups:            624         Scale:                  0.0555
# Min. group size:       1           Log-Likelihood:         -278.4493
# Max. group size:       2           Converged:              Yes
# Mean group size:       1.8
# --------------------------------------------------------------------
#                           Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------------
# Intercept                  1.277    0.063 20.395 0.000  1.154  1.399
# av_Pav                     0.007    0.021  0.330 0.741 -0.034  0.048
# exclusiontot               0.050    0.025  2.001 0.045  0.001  0.100
# av_Pav:exclusiontot        0.014    0.029  0.492 0.623 -0.043  0.072
# group                     -0.071    0.046 -1.543 0.123 -0.161  0.019
# av_Pav:group               0.024    0.045  0.546 0.585 -0.063  0.112
# exclusiontot:group        -0.044    0.055 -0.802 0.423 -0.151  0.063
# av_Pav:exclusiontot:group  0.072    0.062  1.149 0.251 -0.051  0.194
# time                      -0.167    0.020 -8.481 0.000 -0.205 -0.128
# age                       -0.006    0.001 -7.343 0.000 -0.007 -0.004
# education                  0.019    0.020  0.949 0.343 -0.020  0.059
# sex                        0.011    0.023  0.485 0.627 -0.033  0.055
# subject Var                0.041    0.027
# subject x av_Pav Cov       0.000    0.014
# av_Pav Var                 0.005    0.025
# ====================================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-ad062213571f> in <module>
#       2 mle_df['gadlog'] = np.hstack((df_panda['gad1log'], df_panda['gad3log']))
#       3 for i in parameter_labels:
# ----> 4     model = smf.mixedlm('gadlog ~ ' + i + '*exclusiontot * group + time + age + education + sex', \
#       5                         mle_df, groups= 'subject', re_formula='~' + i, missing='drop').fit()
#       6     print(model.summary())
#
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py in fit(self, start_params, reml, niter_sa, do_cg, fe_pen, cov_pen, free, full_output, method, **fit_kwargs)
#    2189             # Try optimizing one or more times
#    2190             for j in range(len(method)):
# -> 2191                 rslt = super(MixedLM, self).fit(start_params=packed,
#    2192                                                 skip_hessian=True,
#    2193                                                 method=method[j],
#
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     561
#     562         optimizer = Optimizer()
# --> 563         xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     564                                                        fargs, kwargs,
#     565                                                        hessian=hess,
#
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     239
#     240         func = fit_funcs[method]
# --> 241         xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     242                              disp=disp, maxiter=maxiter, callback=callback,
#     243                              retall=retall, full_output=full_output,
#
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/optimizer.py in _fit_cg(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     799     norm = kwargs.setdefault('norm', np.Inf)
#     800     epsilon = kwargs.setdefault('epsilon', 1.4901161193847656e-08)
# --> 801     retvals = optimize.fmin_cg(f, start_params, score, gtol=gtol, norm=norm,
#     802                                epsilon=epsilon, maxiter=maxiter,
#     803                                full_output=full_output, disp=disp,
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/optimize.py in fmin_cg(f, x0, fprime, args, gtol, norm, epsilon, maxiter, full_output, disp, retall, callback)
#    1465             'return_all': retall}
#    1466
# -> 1467     res = _minimize_cg(f, x0, args, fprime, callback=callback, **opts)
#    1468
#    1469     if full_output:
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/optimize.py in _minimize_cg(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, **unknown_options)
#    1584         try:
#    1585             alpha_k, fc, gc, old_fval, old_old_fval, gfkp1 = \
# -> 1586                      _line_search_wolfe12(f, myfprime, xk, pk, gfk, old_fval,
#    1587                                           old_old_fval, c2=0.4, amin=1e-100, amax=1e100,
#    1588                                           extra_condition=descent_condition)
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/optimize.py in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#    1003     extra_condition = kwargs.pop('extra_condition', None)
#    1004
# -> 1005     ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#    1006                              old_fval, old_old_fval,
#    1007                              **kwargs)
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      94     derphi0 = np.dot(gfk, pk)
#      95
# ---> 96     stp, fval, old_fval = scalar_search_wolfe1(
#      97             phi, derphi, old_fval, old_old_fval, derphi0,
#      98             c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     170         if task[:2] == b'FG':
#     171             alpha1 = stp
# --> 172             phi1 = phi(stp)
#     173             derphi1 = derphi(stp)
#     174         else:
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/linesearch.py in phi(s)
#      82     def phi(s):
#      83         fc[0] += 1
# ---> 84         return f(xk + s*pk, *args)
#      85
#      86     def derphi(s):
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun(self, x)
#     247         if not np.array_equal(x, self.x):
#     248             self._update_x_impl(x)
# --> 249         self._update_fun()
#     250         return self.f
#     251
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     231     def _update_fun(self):
#     232         if not self.f_updated:
# --> 233             self._update_fun_impl()
#     234             self.f_updated = True
#     235
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     135
#     136         def update_fun():
# --> 137             self.f = fun_wrapped(self.x)
#     138
#     139         self._update_fun_impl = update_fun
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     132             # Overwriting results in undefined behaviour because
#     133             # fun(self.x) will change self.x, with the two no longer linked.
# --> 134             return fun(np.copy(x), *args)
#     135
#     136         def update_fun():
#
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py in f(params, *args)
#     529
#     530         def f(params, *args):
# --> 531             return -self.loglike(params, *args) / nobs
#     532
#     533         if method == 'newton':
#
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py in loglike(self, params, profile_fe)
#    1496         # Move to the profile set
#    1497         if profile_fe:
# -> 1498             fe_params, sing = self.get_fe_params(cov_re, vcomp)
#    1499             if sing:
#    1500                 self._cov_sing += 1
#
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py in get_fe_params(self, cov_re, vcomp, tol)
#    1336             exog = self.exog_li[group_ix]
#    1337             ex_r, ex2_r = self._aex_r[group_ix], self._aex_r2[group_ix]
# -> 1338             solver = _smw_solver(1., ex_r, ex2_r, cov_re_inv, vc_vari)
#    1339             u = solver(self._endex_li[group_ix])
#    1340             xtxy += np.dot(exog.T, u)
#
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py in _smw_solver(s, A, AtA, Qi, di)
#     499         d = qmat.shape[0]
#     500         qmat.flat[m*(d+1)::d+1] += di
# --> 501         qmati = np.linalg.solve(qmat, A.T)
#     502
#     503         def solver(rhs):
#
# <__array_function__ internals> in solve(*args, **kwargs)
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py in solve(a, b)
#     392     signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     393     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 394     r = gufunc(a, b, signature=signature, extobj=extobj)
#     395
#     396     return wrap(r.astype(result_t, copy=False))
#
# KeyboardInterrupt:

# %%
# do cognitive parameters differ between drug group in the included group?
for i in parameter_labels[:-1]:
    model = smf.mixedlm(i + ' ~ group + time + site + cis + dep + age + education + AD_past + marstat', \
                        mle_df[mle_df['exclusiontot']==0], groups= 'subject', missing='drop').fit()
    print(model.summary())
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: rew_se
# No. Observations: 540     Method:             REML
# No. Groups:       372     Scale:              0.9804
# Min. group size:  1       Log-Likelihood:     -776.1123
# Max. group size:  2       Converged:          Yes
# Mean group size:  1.5
# -------------------------------------------------------
#              Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept     3.927    0.352 11.154 0.000  3.237  4.617
# group         0.330    0.121  2.719 0.007  0.092  0.567
# time         -0.155    0.100 -1.548 0.122 -0.351  0.041
# site         -0.086    0.039 -2.223 0.026 -0.162 -0.010
# cis          -0.041    0.056 -0.724 0.469 -0.151  0.070
# dep          -0.091    0.094 -0.968 0.333 -0.276  0.093
# age          -0.005    0.004 -1.439 0.150 -0.012  0.002
# education    -0.367    0.099 -3.707 0.000 -0.561 -0.173
# AD_past       0.179    0.088  2.027 0.043  0.006  0.353
# marstat      -0.018    0.067 -0.273 0.785 -0.150  0.114
# subject Var   0.000    0.090
# =======================================================
#
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: loss_se
# No. Observations: 540     Method:             REML
# No. Groups:       372     Scale:              0.6698
# Min. group size:  1       Log-Likelihood:     -724.4871
# Max. group size:  2       Converged:          Yes
# Mean group size:  1.5
# -------------------------------------------------------
#              Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept     1.651    0.328  5.030 0.000  1.008  2.295
# group        -0.110    0.109 -1.003 0.316 -0.324  0.105
# time          0.271    0.087  3.126 0.002  0.101  0.441
# site          0.019    0.037  0.505 0.614 -0.053  0.091
# cis          -0.063    0.054 -1.157 0.247 -0.169  0.044
# dep          -0.039    0.090 -0.433 0.665 -0.216  0.138
# age          -0.006    0.003 -1.642 0.101 -0.012  0.001
# education    -0.092    0.094 -0.984 0.325 -0.276  0.091
# AD_past      -0.098    0.085 -1.162 0.245 -0.265  0.068
# marstat      -0.026    0.064 -0.406 0.685 -0.151  0.099
# subject Var   0.146    0.095
# =======================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: rew_LR
# No. Observations: 540     Method:             REML
# No. Groups:       372     Scale:              1.3374
# Min. group size:  1       Log-Likelihood:     -858.3966
# Max. group size:  2       Converged:          Yes
# Mean group size:  1.5
# -------------------------------------------------------
#              Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept    -2.022    0.410 -4.936 0.000 -2.825 -1.219
# group        -0.093    0.141 -0.656 0.512 -0.370  0.184
# time          0.342    0.117  2.932 0.003  0.113  0.571
# site         -0.009    0.045 -0.204 0.838 -0.097  0.079
# cis          -0.125    0.066 -1.895 0.058 -0.254  0.004
# dep           0.052    0.110  0.476 0.634 -0.163  0.268
# age          -0.012    0.004 -2.806 0.005 -0.020 -0.004
# education     0.221    0.115  1.915 0.056 -0.005  0.447
# AD_past      -0.106    0.103 -1.023 0.306 -0.308  0.097
# marstat       0.017    0.079  0.211 0.833 -0.137  0.170
# subject Var   0.000    0.089
# =======================================================
#
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: loss_LR
# No. Observations: 540     Method:             REML
# No. Groups:       372     Scale:              2.0124
# Min. group size:  1       Log-Likelihood:     -982.1045
# Max. group size:  2       Converged:          Yes
# Mean group size:  1.5
# -------------------------------------------------------
#              Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept    -0.322    0.522 -0.617 0.537 -1.346  0.701
# group         0.596    0.179  3.334 0.001  0.245  0.946
# time         -0.367    0.146 -2.522 0.012 -0.653 -0.082
# site         -0.048    0.058 -0.828 0.407 -0.161  0.065
# cis          -0.050    0.085 -0.590 0.555 -0.216  0.116
# dep          -0.026    0.141 -0.181 0.856 -0.303  0.251
# age          -0.011    0.005 -2.073 0.038 -0.022 -0.001
# education    -0.056    0.148 -0.378 0.706 -0.345  0.234
# AD_past       0.319    0.133  2.401 0.016  0.059  0.579
# marstat       0.013    0.101  0.125 0.900 -0.185  0.210
# subject Var   0.124    0.127
# =======================================================
#
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: app_Pav
# No. Observations: 540     Method:             REML
# No. Groups:       372     Scale:              0.2320
# Min. group size:  1       Log-Likelihood:     -422.0284
# Max. group size:  2       Converged:          Yes
# Mean group size:  1.5
# -------------------------------------------------------
#              Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept    -0.394    0.184 -2.141 0.032 -0.755 -0.033
# group         0.094    0.062  1.510 0.131 -0.028  0.216
# time         -0.087    0.050 -1.733 0.083 -0.186  0.011
# site         -0.053    0.020 -2.578 0.010 -0.093 -0.013
# cis           0.032    0.030  1.079 0.281 -0.026  0.091
# dep          -0.085    0.050 -1.713 0.087 -0.183  0.012
# age           0.008    0.002  4.376 0.000  0.005  0.012
# education    -0.034    0.052 -0.664 0.507 -0.136  0.067
# AD_past       0.095    0.047  2.038 0.042  0.004  0.187
# marstat      -0.025    0.035 -0.698 0.485 -0.094  0.045
# subject Var   0.027    0.048
# =======================================================
#
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: av_Pav
# No. Observations: 540     Method:             REML
# No. Groups:       372     Scale:              0.3290
# Min. group size:  1       Log-Likelihood:     -589.9481
# Max. group size:  2       Converged:          Yes
# Mean group size:  1.5
# -------------------------------------------------------
#              Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept    -1.307    0.263 -4.959 0.000 -1.823 -0.790
# group        -0.181    0.084 -2.165 0.030 -0.345 -0.017
# time          0.059    0.064  0.919 0.358 -0.067  0.185
# site         -0.005    0.030 -0.166 0.868 -0.064  0.054
# cis           0.065    0.044  1.460 0.144 -0.022  0.152
# dep          -0.036    0.074 -0.491 0.624 -0.181  0.108
# age           0.013    0.003  4.497 0.000  0.007  0.018
# education     0.119    0.076  1.559 0.119 -0.030  0.268
# AD_past      -0.049    0.069 -0.712 0.477 -0.186  0.087
# marstat       0.030    0.052  0.578 0.563 -0.072  0.132
# subject Var   0.178    0.094
# =======================================================
#
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: noise
# No. Observations: 540     Method:             REML
# No. Groups:       372     Scale:              1.0255
# Min. group size:  1       Log-Likelihood:     -822.6698
# Max. group size:  2       Converged:          Yes
# Mean group size:  1.5
# -------------------------------------------------------
#              Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept     2.318    0.394  5.890 0.000  1.547  3.089
# group        -0.129    0.132 -0.976 0.329 -0.388  0.130
# time          0.129    0.106  1.221 0.222 -0.078  0.337
# site          0.112    0.044  2.555 0.011  0.026  0.197
# cis           0.036    0.064  0.564 0.573 -0.090  0.162
# dep           0.118    0.107  1.101 0.271 -0.092  0.327
# age          -0.003    0.004 -0.779 0.436 -0.011  0.005
# education     0.048    0.112  0.432 0.666 -0.171  0.268
# AD_past      -0.140    0.101 -1.390 0.164 -0.337  0.057
# marstat       0.059    0.076  0.770 0.441 -0.091  0.208
# subject Var   0.150    0.111
# =======================================================
#
#          Mixed Linear Model Regression Results
# =======================================================
# Model:            MixedLM Dependent Variable: bias
# No. Observations: 540     Method:             REML
# No. Groups:       372     Scale:              0.5716
# Min. group size:  1       Log-Likelihood:     -710.5701
# Max. group size:  2       Converged:          Yes
# Mean group size:  1.5
# -------------------------------------------------------
#              Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------
# Intercept     0.966    0.326  2.960 0.003  0.326  1.605
# group         0.032    0.106  0.303 0.762 -0.176  0.240
# time          0.299    0.083  3.621 0.000  0.137  0.462
# site         -0.030    0.037 -0.823 0.411 -0.102  0.042
# cis          -0.089    0.054 -1.629 0.103 -0.195  0.018
# dep           0.027    0.090  0.298 0.766 -0.150  0.204
# age          -0.028    0.003 -8.239 0.000 -0.035 -0.022
# education     0.036    0.093  0.384 0.701 -0.147  0.219
# AD_past       0.046    0.085  0.543 0.587 -0.120  0.213
# marstat      -0.064    0.064 -0.998 0.318 -0.189  0.062
# subject Var   0.214    0.107
# =======================================================

# %%
# does the random bias differ between drug group in the excluded group?
for i in parameter_labels[:-1]:
    model = smf.mixedlm('rbias ~ group + time + site + cis + dep + age + education + AD_past + marstat', \
                        mle_df[mle_df['exclusiontot']==1], groups= 'subject', missing='drop').fit()
    print(model.summary())

# %%
# do cognitive parameters have an effect on gad at 6 weeks in the included group controlled drug group?
mle_df['gadlog'] = np.hstack((df_panda['gad1log'], df_panda['gad3log']))
for i in parameter_labels[:-1]:
    model = smf.mixedlm('gadlog ~ ' + i + ' + group + time + age + education + sex + AD_past', \
                        mle_df[mle_df['exclusiontot']==0], groups= 'subject', re_formula='~' + i, missing='drop').fit()
    print(model.summary())
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2131: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2131: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2137: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2149: ConvergenceWarning: Gradient optimization failed, |grad| = 178.822048
#   warnings.warn(msg, ConvergenceWarning)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#              Mixed Linear Model Regression Results
# ===============================================================
# Model:                MixedLM   Dependent Variable:   gadlog
# No. Observations:     1134      Method:               REML
# No. Groups:           624       Scale:                0.0285
# Min. group size:      1         Log-Likelihood:       -140.1778
# Max. group size:      2         Converged:            No
# Mean group size:      1.8
# ---------------------------------------------------------------
#                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------
# Intercept             1.081    0.060 18.019 0.000  0.963  1.198
# rew_se               -0.002    0.008 -0.284 0.776 -0.019  0.014
# group                -0.036    0.020 -1.792 0.073 -0.076  0.003
# time                 -0.042    0.008 -5.543 0.000 -0.056 -0.027
# age                  -0.004    0.001 -5.676 0.000 -0.006 -0.003
# education             0.024    0.018  1.310 0.190 -0.012  0.060
# sex                   0.020    0.022  0.922 0.357 -0.023  0.063
# AD_past              -0.012    0.024 -0.490 0.624 -0.059  0.035
# subject Var           0.041    0.126
# subject x rew_se Cov -0.009    0.060
# rew_se Var            0.009    0.040
# ===============================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#              Mixed Linear Model Regression Results
# ================================================================
# Model:               MixedLM    Dependent Variable:    gadlog
# No. Observations:    1134       Method:                REML
# No. Groups:          624        Scale:                 0.0336
# Min. group size:     1          Log-Likelihood:        -117.8068
# Max. group size:     2          Converged:             Yes
# Mean group size:     1.8
# ----------------------------------------------------------------
#                       Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------
# Intercept              1.060    0.057 18.432 0.000  0.947  1.172
# loss_se               -0.004    0.007 -0.529 0.597 -0.018  0.010
# group                 -0.041    0.021 -2.004 0.045 -0.082 -0.001
# time                  -0.042    0.008 -5.447 0.000 -0.057 -0.027
# age                   -0.005    0.001 -6.132 0.000 -0.006 -0.003
# education              0.022    0.019  1.128 0.259 -0.016  0.059
# sex                    0.024    0.022  1.083 0.279 -0.019  0.067
# AD_past                0.006    0.023  0.275 0.783 -0.039  0.052
# subject Var            0.053    0.041
# subject x loss_se Cov -0.001    0.013
# loss_se Var            0.000    0.010
# ================================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2131: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2131: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2137: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2149: ConvergenceWarning: Gradient optimization failed, |grad| = 253.207641
#   warnings.warn(msg, ConvergenceWarning)
#              Mixed Linear Model Regression Results
# ===============================================================
# Model:                MixedLM   Dependent Variable:   gadlog
# No. Observations:     1134      Method:               REML
# No. Groups:           624       Scale:                0.0267
# Min. group size:      1         Log-Likelihood:       -176.6929
# Max. group size:      2         Converged:            No
# Mean group size:      1.8
# ---------------------------------------------------------------
#                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------
# Intercept             1.064    0.055 19.431 0.000  0.957  1.171
# rew_LR               -0.008    0.007 -1.230 0.219 -0.021  0.005
# group                -0.041    0.021 -2.021 0.043 -0.082 -0.001
# time                 -0.038    0.008 -4.994 0.000 -0.053 -0.023
# age                  -0.005    0.001 -6.916 0.000 -0.007 -0.004
# education             0.011    0.019  0.583 0.560 -0.026  0.049
# sex                   0.014    0.021  0.653 0.514 -0.028  0.056
# AD_past               0.016    0.022  0.692 0.489 -0.028  0.060
# subject Var           0.044
# subject x rew_LR Cov  0.012
# rew_LR Var            0.010
# ===============================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2131: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2131: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2137: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2149: ConvergenceWarning: Gradient optimization failed, |grad| = 82.845013
#   warnings.warn(msg, ConvergenceWarning)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#              Mixed Linear Model Regression Results
# ================================================================
# Model:               MixedLM    Dependent Variable:    gadlog
# No. Observations:    1134       Method:                REML
# No. Groups:          624        Scale:                 0.0272
# Min. group size:     1          Log-Likelihood:        -132.0729
# Max. group size:     2          Converged:             No
# Mean group size:     1.8
# ----------------------------------------------------------------
#                       Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------
# Intercept              1.052    0.059 17.972 0.000  0.938  1.167
# loss_LR                0.001    0.005  0.271 0.787 -0.008  0.011
# group                 -0.039    0.020 -1.916 0.055 -0.078  0.001
# time                  -0.043    0.007 -5.787 0.000 -0.057 -0.028
# age                   -0.005    0.001 -5.693 0.000 -0.006 -0.003
# education              0.024    0.020  1.219 0.223 -0.015  0.063
# sex                    0.022    0.023  0.948 0.343 -0.023  0.066
# AD_past                0.006    0.024  0.243 0.808 -0.041  0.053
# subject Var            0.068    0.101
# subject x loss_LR Cov  0.007    0.027
# loss_LR Var            0.003    0.014
# ================================================================
#
#              Mixed Linear Model Regression Results
# ================================================================
# Model:               MixedLM    Dependent Variable:    gadlog
# No. Observations:    1134       Method:                REML
# No. Groups:          624        Scale:                 0.0293
# Min. group size:     1          Log-Likelihood:        -112.9214
# Max. group size:     2          Converged:             Yes
# Mean group size:     1.8
# ----------------------------------------------------------------
#                       Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------
# Intercept              1.055    0.057 18.567 0.000  0.943  1.166
# app_Pav                0.013    0.016  0.832 0.405 -0.018  0.044
# group                 -0.044    0.020 -2.166 0.030 -0.084 -0.004
# time                  -0.040    0.008 -5.316 0.000 -0.055 -0.025
# age                   -0.005    0.001 -6.077 0.000 -0.006 -0.003
# education              0.024    0.019  1.252 0.211 -0.014  0.062
# sex                    0.028    0.022  1.256 0.209 -0.016  0.071
# AD_past                0.003    0.023  0.108 0.914 -0.043  0.048
# subject Var            0.053    0.040
# subject x app_Pav Cov  0.005    0.025
# app_Pav Var            0.016    0.043
# ================================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#              Mixed Linear Model Regression Results
# ===============================================================
# Model:                MixedLM   Dependent Variable:   gadlog
# No. Observations:     1134      Method:               REML
# No. Groups:           624       Scale:                0.0333
# Min. group size:      1         Log-Likelihood:       -116.2384
# Max. group size:      2         Converged:            Yes
# Mean group size:      1.8
# ---------------------------------------------------------------
#                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------
# Intercept             1.060    0.057 18.638 0.000  0.948  1.171
# av_Pav                0.010    0.012  0.904 0.366 -0.012  0.033
# group                -0.042    0.021 -2.025 0.043 -0.082 -0.001
# time                 -0.041    0.008 -5.454 0.000 -0.056 -0.026
# age                  -0.005    0.001 -6.288 0.000 -0.006 -0.003
# education             0.024    0.019  1.231 0.218 -0.014  0.061
# sex                   0.024    0.022  1.083 0.279 -0.019  0.067
# AD_past               0.009    0.023  0.397 0.691 -0.036  0.055
# subject Var           0.048    0.032
# subject x av_Pav Cov -0.003    0.015
# av_Pav Var            0.000    0.024
# ===============================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2131: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2189: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM   Dependent Variable:   gadlog
# No. Observations:    1134      Method:               REML
# No. Groups:          624       Scale:                0.0221
# Min. group size:     1         Log-Likelihood:       -211.8864
# Max. group size:     2         Converged:            Yes
# Mean group size:     1.8
# --------------------------------------------------------------
#                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept            1.062    0.062 17.205 0.000  0.941  1.183
# noise                0.002    0.006  0.246 0.806 -0.011  0.014
# group               -0.042    0.019 -2.153 0.031 -0.080 -0.004
# time                -0.036    0.007 -5.163 0.000 -0.050 -0.023
# age                 -0.005    0.001 -6.203 0.000 -0.007 -0.004
# education            0.000    0.021  0.005 0.996 -0.041  0.041
# sex                  0.034    0.024  1.460 0.144 -0.012  0.081
# AD_past              0.015    0.025  0.583 0.560 -0.034  0.063
# subject Var          0.041    0.034
# subject x noise Cov -0.009    0.011
# noise Var            0.011
# ==============================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#             Mixed Linear Model Regression Results
# =============================================================
# Model:              MixedLM   Dependent Variable:   gadlog
# No. Observations:   1134      Method:               REML
# No. Groups:         624       Scale:                0.0335
# Min. group size:    1         Log-Likelihood:       -116.2035
# Max. group size:    2         Converged:            Yes
# Mean group size:    1.8
# -------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept           1.061    0.057 18.686 0.000  0.949  1.172
# bias               -0.012    0.007 -1.790 0.074 -0.026  0.001
# group              -0.041    0.021 -2.015 0.044 -0.082 -0.001
# time               -0.040    0.008 -5.284 0.000 -0.055 -0.025
# age                -0.005    0.001 -6.359 0.000 -0.007 -0.004
# education           0.025    0.019  1.311 0.190 -0.012  0.063
# sex                 0.023    0.022  1.059 0.290 -0.020  0.066
# AD_past             0.008    0.023  0.357 0.721 -0.037  0.054
# subject Var         0.050    0.032
# subject x bias Cov  0.001    0.008
# bias Var            0.000    0.006
# =============================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM   Dependent Variable:   gadlog
# No. Observations:    1134      Method:               REML
# No. Groups:          624       Scale:                0.0332
# Min. group size:     1         Log-Likelihood:       -113.9638
# Max. group size:     2         Converged:            Yes
# Mean group size:     1.8
# --------------------------------------------------------------
#                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept            1.064    0.056 18.889 0.000  0.954  1.175
# rbias               -0.019    0.008 -2.292 0.022 -0.035 -0.003
# group               -0.040    0.021 -1.926 0.054 -0.080  0.001
# time                -0.041    0.008 -5.376 0.000 -0.056 -0.026
# age                 -0.005    0.001 -6.486 0.000 -0.007 -0.004
# education            0.025    0.019  1.296 0.195 -0.013  0.062
# sex                  0.021    0.022  0.957 0.339 -0.022  0.064
# AD_past              0.010    0.023  0.413 0.680 -0.036  0.055
# subject Var          0.050    0.032
# subject x rbias Cov  0.003    0.011
# rbias Var            0.001    0.008
# ==============================================================
#
# ------------------------------------INCLUDED--------------------------------------
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#              Mixed Linear Model Regression Results
# ===============================================================
# Model:               MixedLM    Dependent Variable:    gadlog
# No. Observations:    529        Method:                REML
# No. Groups:          368        Scale:                 0.0286
# Min. group size:     1          Log-Likelihood:        -72.2056
# Max. group size:     2          Converged:             Yes
# Mean group size:     1.4
# ---------------------------------------------------------------
#                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------
# Intercept             0.927    0.088 10.516 0.000  0.754  1.099
# rew_se                0.011    0.012  0.898 0.369 -0.013  0.034
# group                -0.014    0.031 -0.445 0.657 -0.074  0.047
# time                 -0.042    0.011 -3.878 0.000 -0.064 -0.021
# age                  -0.005    0.001 -4.200 0.000 -0.007 -0.003
# education             0.043    0.032  1.352 0.176 -0.019  0.106
# sex                   0.044    0.030  1.497 0.135 -0.014  0.102
# AD_past               0.023    0.030  0.765 0.444 -0.036  0.083
# subject Var           0.059    0.217
# subject x rew_se Cov -0.003    0.055
# rew_se Var            0.001    0.017
# ===============================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2131: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#              Mixed Linear Model Regression Results
# ================================================================
# Model:                MixedLM    Dependent Variable:    gadlog
# No. Observations:     529        Method:                REML
# No. Groups:           368        Scale:                 0.0299
# Min. group size:      1          Log-Likelihood:        -70.8741
# Max. group size:      2          Converged:             Yes
# Mean group size:      1.4
# ----------------------------------------------------------------
#                       Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------
# Intercept              0.991    0.081 12.178 0.000  0.831  1.150
# loss_se               -0.020    0.013 -1.596 0.111 -0.045  0.005
# group                 -0.010    0.030 -0.333 0.739 -0.069  0.049
# time                  -0.042    0.011 -3.799 0.000 -0.063 -0.020
# age                   -0.005    0.001 -4.240 0.000 -0.007 -0.003
# education              0.037    0.032  1.157 0.247 -0.026  0.100
# sex                    0.044    0.029  1.505 0.132 -0.013  0.102
# AD_past                0.027    0.030  0.883 0.377 -0.033  0.086
# subject Var            0.044    0.098
# subject x loss_se Cov  0.003    0.036
# loss_se Var            0.000    0.026
# ================================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2131: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#              Mixed Linear Model Regression Results
# ===============================================================
# Model:               MixedLM    Dependent Variable:    gadlog
# No. Observations:    529        Method:                REML
# No. Groups:          368        Scale:                 0.0299
# Min. group size:     1          Log-Likelihood:        -71.9254
# Max. group size:     2          Converged:             Yes
# Mean group size:     1.4
# ---------------------------------------------------------------
#                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------
# Intercept             0.940    0.081 11.666 0.000  0.782  1.098
# rew_LR               -0.006    0.009 -0.684 0.494 -0.023  0.011
# group                -0.009    0.030 -0.286 0.775 -0.068  0.051
# time                 -0.043    0.011 -3.972 0.000 -0.065 -0.022
# age                  -0.005    0.001 -4.288 0.000 -0.007 -0.003
# education             0.044    0.032  1.379 0.168 -0.018  0.106
# sex                   0.044    0.029  1.485 0.138 -0.014  0.101
# AD_past               0.029    0.030  0.960 0.337 -0.030  0.088
# subject Var           0.065    0.106
# subject x rew_LR Cov  0.003    0.022
# rew_LR Var            0.000    0.008
# ===============================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2131: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2131: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2137: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2149: ConvergenceWarning: Gradient optimization failed, |grad| = 0.015424
#   warnings.warn(msg, ConvergenceWarning)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#              Mixed Linear Model Regression Results
# ================================================================
# Model:                MixedLM    Dependent Variable:    gadlog
# No. Observations:     529        Method:                REML
# No. Groups:           368        Scale:                 0.0297
# Min. group size:      1          Log-Likelihood:        -71.5310
# Max. group size:      2          Converged:             No
# Mean group size:      1.4
# ----------------------------------------------------------------
#                       Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------
# Intercept              0.972    0.079 12.360 0.000  0.818  1.127
# loss_LR                0.012    0.007  1.711 0.087 -0.002  0.026
# group                 -0.017    0.031 -0.546 0.585 -0.076  0.043
# time                  -0.043    0.011 -3.920 0.000 -0.064 -0.021
# age                   -0.005    0.001 -4.025 0.000 -0.007 -0.002
# education              0.040    0.032  1.272 0.203 -0.022  0.103
# sex                    0.044    0.029  1.494 0.135 -0.014  0.102
# AD_past                0.022    0.030  0.738 0.460 -0.037  0.082
# subject Var            0.049    0.068
# subject x loss_LR Cov -0.001    0.011
# loss_LR Var            0.000    0.005
# ================================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#              Mixed Linear Model Regression Results
# ================================================================
# Model:                MixedLM    Dependent Variable:    gadlog
# No. Observations:     529        Method:                REML
# No. Groups:           368        Scale:                 0.0290
# Min. group size:      1          Log-Likelihood:        -71.5128
# Max. group size:      2          Converged:             Yes
# Mean group size:      1.4
# ----------------------------------------------------------------
#                       Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------
# Intercept              0.976    0.080 12.222 0.000  0.820  1.133
# app_Pav                0.023    0.022  1.056 0.291 -0.020  0.066
# group                 -0.010    0.030 -0.319 0.750 -0.069  0.049
# time                  -0.043    0.011 -4.014 0.000 -0.064 -0.022
# age                   -0.005    0.001 -4.318 0.000 -0.007 -0.003
# education              0.041    0.032  1.276 0.202 -0.022  0.103
# sex                    0.044    0.030  1.486 0.137 -0.014  0.102
# AD_past                0.023    0.030  0.767 0.443 -0.036  0.083
# subject Var            0.054    0.067
# subject x app_Pav Cov  0.002    0.036
# app_Pav Var            0.003    0.056
# ================================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#              Mixed Linear Model Regression Results
# ===============================================================
# Model:               MixedLM    Dependent Variable:    gadlog
# No. Observations:    529        Method:                REML
# No. Groups:          368        Scale:                 0.0296
# Min. group size:     1          Log-Likelihood:        -72.4216
# Max. group size:     2          Converged:             Yes
# Mean group size:     1.4
# ---------------------------------------------------------------
#                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------
# Intercept             0.967    0.081 11.991 0.000  0.809  1.125
# av_Pav                0.005    0.017  0.278 0.781 -0.028  0.038
# group                -0.007    0.030 -0.221 0.825 -0.066  0.053
# time                 -0.045    0.011 -4.135 0.000 -0.066 -0.023
# age                  -0.005    0.001 -4.165 0.000 -0.007 -0.003
# education             0.039    0.032  1.232 0.218 -0.023  0.102
# sex                   0.044    0.030  1.472 0.141 -0.014  0.101
# AD_past               0.026    0.030  0.841 0.401 -0.034  0.085
# subject Var           0.053    0.072
# subject x av_Pav Cov  0.000    0.028
# av_Pav Var            0.001    0.031
# ===============================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2131: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2131: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2137: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2149: ConvergenceWarning: Gradient optimization failed, |grad| = 60.212636
#   warnings.warn(msg, ConvergenceWarning)
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:                MixedLM   Dependent Variable:   gadlog
# No. Observations:     529       Method:               REML
# No. Groups:           368       Scale:                0.0293
# Min. group size:      1         Log-Likelihood:       -81.1579
# Max. group size:      2         Converged:            No
# Mean group size:      1.4
# --------------------------------------------------------------
#                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept            0.997    0.085 11.800 0.000  0.832  1.163
# noise               -0.008    0.011 -0.694 0.487 -0.029  0.014
# group               -0.004    0.031 -0.131 0.896 -0.066  0.057
# time                -0.043    0.011 -3.784 0.000 -0.065 -0.021
# age                 -0.005    0.001 -4.253 0.000 -0.007 -0.003
# education            0.020    0.036  0.560 0.576 -0.050  0.090
# sex                  0.052    0.030  1.738 0.082 -0.007  0.110
# AD_past              0.026    0.030  0.873 0.383 -0.033  0.085
# subject Var          0.043    0.251
# subject x noise Cov -0.005    0.103
# noise Var            0.004    0.056
# ==============================================================
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#             Mixed Linear Model Regression Results
# =============================================================
# Model:               MixedLM   Dependent Variable:   gadlog
# No. Observations:    529       Method:               REML
# No. Groups:          368       Scale:                0.0288
# Min. group size:     1         Log-Likelihood:       -72.0478
# Max. group size:     2         Converged:            Yes
# Mean group size:     1.4
# -------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept           0.966    0.081 11.977 0.000  0.808  1.124
# bias                0.002    0.014  0.173 0.863 -0.024  0.029
# group              -0.004    0.030 -0.130 0.897 -0.063  0.055
# time               -0.046    0.011 -4.212 0.000 -0.067 -0.024
# age                -0.005    0.001 -4.060 0.000 -0.007 -0.003
# education           0.037    0.032  1.168 0.243 -0.025  0.100
# sex                 0.045    0.030  1.518 0.129 -0.013  0.103
# AD_past             0.026    0.030  0.867 0.386 -0.033  0.086
# subject Var         0.054    0.063
# subject x bias Cov -0.003    0.018
# bias Var            0.002    0.022
# =============================================================
#
# ------------------------------------EXCLUDED--------------------------------------
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2168: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:                MixedLM   Dependent Variable:   gadlog
# No. Observations:     605       Method:               REML
# No. Groups:           421       Scale:                0.0358
# Min. group size:      1         Log-Likelihood:       -99.9892
# Max. group size:      2         Converged:            Yes
# Mean group size:      1.4
# --------------------------------------------------------------
#                     Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept            1.145    0.076 15.023 0.000  0.995  1.294
# rbias               -0.018    0.009 -1.921 0.055 -0.036  0.000
# group               -0.077    0.032 -2.399 0.016 -0.139 -0.014
# time                -0.030    0.013 -2.398 0.016 -0.055 -0.006
# age                 -0.005    0.001 -5.500 0.000 -0.007 -0.004
# education            0.016    0.022  0.719 0.472 -0.028  0.060
# sex                 -0.002    0.028 -0.064 0.949 -0.057  0.054
# AD_past              0.002    0.031  0.072 0.943 -0.058  0.062
# subject Var          0.052    0.050
# subject x rbias Cov  0.003    0.013
# rbias Var            0.000    0.010
# ==============================================================

# %%
# do rbias have an effect on gad at 6 weeks in the excluded group controlled drug group?
mle_df['gadlog'] = np.hstack((df_panda['gad1log'], df_panda['gad3log']))
model = smf.mixedlm('gadlog ~ rbias + group + time + age + education + sex + AD_past', \
                    mle_df[mle_df['exclusiontot']==1], groups= 'subject', re_formula='~rbias', missing='drop').fit()
print(model.summary())

# %%
# difference in cognitive parameters at session 2
clrs = sns.color_palette("husl", 5)
fig, ax = plt.subplots(2,4,figsize=(20, 10))
j = 0
k = 0
for i in parameter_labels[:-1]:
    clrs = sns.color_palette("husl", 5)
    b = sns.barplot(data=pd.concat((df_panda[i + str(2)][df_panda['group']==0], \
                                    df_panda[i + str(2)][df_panda['group']==1]),\
                                   axis=1,ignore_index=True), capsize=.1, ci="sd", palette=clrs, ax=ax[j,k]);
    sns.stripplot(data=pd.concat((df_panda[i + str(2)][df_panda['group']==0], \
                                  df_panda[i + str(2)][df_panda['group']==1]),\
                                 axis=1,ignore_index=True), color="0", alpha=.1, ax=ax[j,k]);
    b.set_ylabel(i,size=18);
    if j == 1: b.set_xticklabels(['placebo','sertraline'],size=18,rotation=30,ha='right');
    
    k += 1
    if k == 4:
        j += 1
        k = 0
